# %% [markdown]
# # helper code for visualizing and other

# %%
import copy
import numpy as np
import os
import sys


def get_class_info(c, sort_by_type=True, include_underscore_vars=False, return_name_and_type=False, end_prev_len=40):
    def get_len_or_shape(x_in):
        which_one = None
        try:
            len_or_shape_out = str(len(x_in))
            which_one = 'length'
            if type(x_in).__module__ == np.__name__:
                len_or_shape_out = str(x_in.shape)
                which_one = 'shape '
        except:
            if which_one is None:
                len_or_shape_out = 'None'
                which_one = 'None  '
        return len_or_shape_out, which_one

    names = []
    len_or_shape = []
    len_or_shape_which_one = []
    type_to_print = []

    for k in dir(c):
        if include_underscore_vars is False and k[0] != '_':

            tmp1 = str(type(eval('c.' + k)))
            type_to_print.append(tmp1.split("""'""")[-2])
            names.append(k)
            a, b = get_len_or_shape(eval('c.' + names[-1]))
            len_or_shape.append(a)
            len_or_shape_which_one.append(b)
        elif include_underscore_vars:
            tmp1 = str(type(eval('c.' + k)))
            type_to_print.append(tmp1.split("""'""")[-2])
            names.append(k)
            a, b = get_len_or_shape(eval('c.' + names[-1]))
            len_or_shape.append(a)
            len_or_shape_which_one.append(b)
    len_space = ' ' * max(len(k) for k in names)
    len_space_type = ' ' * max(len(k) for k in type_to_print)
    len_space_shape = ' ' * max(len(k) for k in len_or_shape)
    if sort_by_type:
        ind_array = np.argsort(type_to_print)
    else:
        ind_array = np.argsort(names)

    for i in ind_array:
        k1 = names[i]
        k2 = type_to_print[i]
        k5 = len_or_shape[i]
        x = eval('c.' + names[i])
        k3 = str(x)
        k1 = (k1 + len_space)[:len(len_space)]
        k2 = (k2 + len_space_type)[:len(len_space_type)]
        k5 = (k5 + len_space_shape)[:len(len_space_shape)]
        if len(k3) > end_prev_len:
            k3 = '...' + k3[-end_prev_len:]
        else:
            k3 = '> ' + k3[-end_prev_len:]
        print(k1 + ' type->   ' + k2 + '  ' + len_or_shape_which_one[i] + '->   ' + k5 + '  ' + k3)
    if return_name_and_type:
        return names, type_to_print


def get_dict_info(c, sort_by_type=True, include_underscore_vars=False, return_name_and_type=False, end_prev_len=40):
    names = []
    type_to_print = []
    for k in c.keys():
        if include_underscore_vars is False and str(k)[0] != '_':
            tmp1 = str(type(c[k]))
            type_to_print.append(tmp1.split("""'""")[-2])
            names.append(str(k))
        elif include_underscore_vars:
            tmp1 = str(type(c[k]))
            type_to_print.append(tmp1.split("""'""")[-2])
            names.append(str(k))
    len_space = ' ' * max(len(k) for k in names)
    len_space_type = ' ' * max(len(k) for k in type_to_print)
    if sort_by_type:
        ind_array = np.argsort(type_to_print)
    else:
        ind_array = np.argsort(names)

    for i in ind_array:
        k1 = names[i]
        k2 = type_to_print[i]

        if names[i] not in list(c.keys()):
          names[i] = eval(names[i])
        try:
            k3 = str(c[names[i]])
        except:
            k3 = str(c[float(names[i])])


        k1 = (k1 + len_space)[:len(len_space)]
        k2 = (k2 + len_space_type)[:len(len_space_type)]

        if len(k3) > end_prev_len:
            k3 = '...' + k3[-end_prev_len:]
        else:
            k3 = '> ' + k3[-end_prev_len:]

        if 'numpy.ndarray' in k2:
            k4 = str(c[names[i]].shape)
            k4_str = '   shape-> '
        else:
            try:
                k4 = str(len(c[names[i]]))
                k4_str = '   len-> '
            except:
                k4_str = '   None->'
                k4 = 'None'

        print(k1 + ' type->   ' + k2 + k4_str + k4 + '  ' + k3)
    if return_name_and_type:
        return names, type_to_print

def get_class_info2(c, sort_by=None, include_underscore_vars=False, return_name_and_type=False, end_prev_len=40):
    def get_len_or_shape(x_in):
        which_one = None
        try:
            len_or_shape_out = str(len(x_in))
            which_one = 'length'
            if type(x_in).__module__ == np.__name__:
                len_or_shape_out = str(x_in.shape)
                which_one = 'shape '
        except:
            if which_one is None:
                len_or_shape_out = 'None'
                which_one = 'None  '
        return len_or_shape_out, which_one

    names = []
    len_or_shape = []
    len_or_shape_which_one = []
    type_to_print = []

    for k in dir(c):
        if include_underscore_vars is False and k[0] != '_':

            tmp1 = str(type(eval('c.' + k)))
            type_to_print.append(tmp1.split("""'""")[-2])
            names.append(k)
            a, b = get_len_or_shape(eval('c.' + names[-1]))
            len_or_shape.append(a)
            len_or_shape_which_one.append(b)
        elif include_underscore_vars:
            tmp1 = str(type(eval('c.' + k)))
            type_to_print.append(tmp1.split("""'""")[-2])
            names.append(k)
            a, b = get_len_or_shape(eval('c.' + names[-1]))
            len_or_shape.append(a)
            len_or_shape_which_one.append(b)
    len_space = ' ' * max(len(k) for k in names)
    len_space_type = ' ' * max(len(k) for k in type_to_print)
    len_space_shape = ' ' * max(len(k) for k in len_or_shape)
    if sort_by is None:
        ind_array = np.arange(len(names))
    elif 'type' in sort_by.lower():
        ind_array = np.argsort(type_to_print)
    elif 'len' in sort_by.lower() or 'shape' in sort_by.lower():
        np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)
        tmp1 = np.asarray([eval(k) for k in len_or_shape])
        tmp1[tmp1 == None] = np.nan
        tmp1 = [np.max(iii) for iii in tmp1]
        ind_array = np.argsort(tmp1)
    elif 'name' in sort_by.lower():
        ind_array = np.argsort(names)
    else:
        ind_array = np.arange(len(names))

    for i in ind_array:
        k1 = names[i]
        k2 = type_to_print[i]
        k5 = len_or_shape[i]
        x = eval('c.' + names[i])
        k3 = str(x)
        k1 = (k1 + len_space)[:len(len_space)]
        k2 = (k2 + len_space_type)[:len(len_space_type)]
        k5 = (k5 + len_space_shape)[:len(len_space_shape)]
        if len(k3) > end_prev_len:
            k3 = '...' + k3[-end_prev_len:]
        else:
            k3 = '> ' + k3[-end_prev_len:]
        print(k1 + ' type->   ' + k2 + '  ' + len_or_shape_which_one[i] + '->   ' + k5 + '  ' + k3)
    if return_name_and_type:
        return names, type_to_print




def info(x):
    if isinstance(x, dict):
        print('type is dict')
        get_dict_info(x)
    elif isinstance(x, list):
        try:
            x = copy.deepcopy(np.asarray(x))
            print('type is list, converting a copy to numpy array to print this info')
            np_stats(x)
        except:
            print(
                "type is a list that can't be converted to a numpy array for printing info or maybe data format is not compatible")

    elif type(x).__module__ == np.__name__:
        print('type is np array')
        np_stats(x)
    else:
        try:
            print('type is ' + str(type(x)) + ' will try printing using "get_class_info2" ')
            get_class_info2(x)
        except:
            print('cant find out what to do with input of type')
            print(type(x))



def np_stats(in_arr):
    print('\nmin', np.min(in_arr))
    print('max', np.max(in_arr))
    print('mean', np.mean(in_arr))
    print('shape', in_arr.shape)
    print('len of unique', len(np.unique(in_arr)))
    print('type', type(in_arr))
    try:
        print('Dtype ', in_arr.dtype)
    except:
        pass

# %%
class info_dict:
    def __init__(self):
        # Part-based color settings
        self.key_color = "\033[1;30m"
        self.type_beginning_color = "\033[90m"
        self.type_color = "\033[34m"  # Blue
        self.len_beginning_color = "\033[90m"
        self.len_value_color = "\033[34m"  # Blue
        self.len_na_color = "\033[90m"
        self.preview_color = "\x1b[91m"  # "\033[38;5;208m"
        self.shape_beginning_color = "\033[90m"  # Dark gray for "shape: "
        self.shape_value_color = "\033[34m"  # Blue for shape's values
        self.reset = "\033[0m"

    def is_numpy_array(self, value):
        return isinstance(value, np.ndarray)

    def get_length_or_shape(self, value):
        if self.is_numpy_array(value):
            return f"{self.shape_beginning_color}shape: {self.reset}{self.shape_value_color}{value.shape}{self.reset}"
        elif hasattr(value, '__len__') and not isinstance(value, str):
            return f"{self.len_value_color}{len(value)}{self.reset}"
        else:
            return f"{self.len_na_color}N/A{self.reset}"

    def format_value(self, value):
        length_or_shape_str = self.get_length_or_shape(value)
        preview_str = str(value)
        preview = f"{preview_str[:100]}..." if len(preview_str) > 100 else preview_str
        preview = f"{self.preview_color}{preview}{self.reset}"
        type_name = f"{self.type_color}{type(value).__name__}{self.reset}"
        label = "shape: " if self.is_numpy_array(value) else "len: "
        type_len_str = f"{self.type_beginning_color}type: {self.reset}{type_name}, {self.len_beginning_color if not self.is_numpy_array(value) else self.shape_beginning_color}{label}{self.reset}{length_or_shape_str}"
        return type_len_str, preview

    def get_max_lengths(self, items):
        max_key_len = max((len(str(key)) for key, _ in items), default=0)
        max_type_len = max((len(self.format_value(value)[0]) for _, value in items), default=0)
        return max_key_len, max_type_len

    def print_filtered_tree(self, current_level, keys_path, prefix='', level=0):
        if not isinstance(current_level, dict):
            print(f"{prefix} {self.format_value(current_level)[0]}")
            return
        keys_to_process = keys_path[level] if level < len(keys_path) else ['*']
        items = [(key, current_level[key]) for key in current_level if '*' in keys_to_process or key in keys_to_process]
        max_key_len, _ = self.get_max_lengths(items)
        for i, (key, value) in enumerate(items):
            type_len_str, preview = self.format_value(value)
            is_last = i == len(items) - 1
            connector = '└── ' if is_last else '├── '
            aligned_key_str = f"{str(key):<{max_key_len}}"
            print(f"{prefix}{connector}{self.key_color}{aligned_key_str}{self.reset}: {type_len_str} {preview}")
            if isinstance(value, dict) and level + 1 < len(keys_path):
                next_prefix = f"{prefix}{'    ' if is_last else '│   '}"
                self.print_filtered_tree(value, keys_path, next_prefix, level + 1)

    @classmethod
    def vis(cls, d, keys_path=None):
        instance = cls()
        if not keys_path:
            all_sub_dirs = [['*']]*100
            instance.print_filtered_tree(d, all_sub_dirs, '')
        else:
            instance.print_filtered_tree(d, keys_path, '')

# # for selecting certain sub paths
# ##### your_dictionary = TAM.optuna
# keys_path = [['Full_model'], ['*'], ['best_value', 'study']]
# info_dict.vis(your_dictionary, keys_path)

# # # for everything
# # info_dict.vis(your_dictionary)

# %%
# list_specific_packages.py
import pkg_resources

# List of packages you want to find versions for
package_list = [
    'pip', 'setuptools', 'wheel', 'numpy', 'pandas', 'tqdm', 
    'python-dotenv', 'natsort', 'matplotlib', 'scikit-learn', 
    'pytz', 'seaborn', 'pyarrow', 'shap', 'joblib', 'optuna', 
    'ipykernel', 'notebook', 'ipywidgets', 'plotly'
]

# Fetch installed packages
installed_packages = {d.project_name.lower(): d.version for d in pkg_resources.working_set}

# Prepare the requirements format
requirements = []
for package in package_list:
    version = installed_packages.get(package.lower())
    if version:
        requirements.append(f"{package}=={version}")

requirements_format = "\n".join(requirements)
print(requirements_format)
# Out:
# pip==24.0
# setuptools==69.2.0
# wheel==0.43.0
# numpy==1.26.4
# pandas==2.2.1
# tqdm==4.66.2
# python-dotenv==1.0.1
# natsort==8.4.0
# matplotlib==3.8.3
# scikit-learn==1.4.1.post1
# pytz==2024.1
# seaborn==0.13.2
# pyarrow==15.0.2
# shap==0.45.0
# joblib==1.3.2
# optuna==3.6.1
# ipykernel==6.29.4
# notebook==7.1.2
# ipywidgets==8.1.2
# plotly==5.20.0

# %% [markdown]
# # actual core code

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
import copy 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

import optuna
from sklearn.model_selection import cross_val_score, StratifiedKFold
from optuna.samplers import TPESampler

# %% [markdown]
# # set up all classes and functions

# %% [markdown]
# ## feature selection class

# %%
class feature_selection():
    def __init__(self, hierarchy_keys, hierarchy_levels, feature_keys, select_top_n_features=30000):
        """
        A class for performing feature selection based on a hierarchical structure of features.
    
        This class supports the identification and selection of top N features based on the interquartile range (IQR),
        within a given hierarchical context (e.g., superfamily, family, class).
    
        Parameters:
        - hierarchy_keys (List[str]): Keys representing the hierarchical levels (e.g., ['Superfamily_code', 'Family_code', 'Class_v12_code']).
        - hierarchy_levels (List[int]): Numeric representation of each level's hierarchy, where lower numbers indicate higher hierarchy levels.
        - feature_keys (List[str]): List of strings representing the features to be considered for selection.
        - select_top_n_features (int): Number of top features to select based on IQR. Set to None to ignore IQR and define a structure to use with RF 
    
        Attributes:
        - feature_dict (dict): A dictionary to store the selected top N features across different hierarchical levels.
        - ordered_hierarchy_keys (List[str]): Sorted list of hierarchy keys based on their levels.
        - feature_keys (List[str]): See parameters.
        - select_top_n_features (int): See parameters.
        """
        if not all(isinstance(item, str) for item in hierarchy_keys):
            raise TypeError("hierarchy_keys must be a list of strings.")
        if not all(isinstance(item, int) for item in hierarchy_levels):
            raise TypeError("hierarchy_levels must be a list of integers.")

        #idx to DataFrame
        self.selected_feature_dict = {} # for each sub model which features are selected?
        self.sample_dict = {} # for each sub model which samples apply?
        self.target_key_dict = {}
            
        
        self.ordered_hierarchy_keys = [key for _, key in sorted(zip(hierarchy_levels, hierarchy_keys))]
        self.n_levels = len(hierarchy_levels)
        
        self.feature_keys = feature_keys
        self.select_top_n_features = select_top_n_features

        
    @staticmethod    
    def _calculate_IQR(betas):
        """
        Calculate the interquartile range (IQR) for each feature in the given pandas Series.
    
        Parameters:
        - betas (pd.Series): Pandas Series containing the values from which to calculate the IQR.
    
        Returns:
        - pd.Series: The IQR for each column in the input series.
        """
        return betas.apply(np.quantile, q=[0.25, 0.75]).diff().iloc[1]

    @staticmethod  
    def _get_top_n_IQR_index(IQR, N):
        """
        Selects the top N indices from a pandas Series based on the Interquartile Range (IQR) values.
    
        Parameters:
        - IQR (pd.Series): A pandas Series containing the interquartile ranges of features.
        - N (int, optional): The number of top indices to select based on the highest IQR values.
                             If N is None, all indices are selected, which is useful for initializing
                             the dictionary without filtering by IQR but requiring all valid model
                             node points (where there is more than one class at the model node).
    
        Returns:
        - pd.Index: An index object containing the top N indices from the IQR Series. If N is None,
                    returns the indices for all entries in the IQR Series.
    
        Raises:
        - TypeError: If the input `IQR` is not a pandas Series.
        """
        if N > len(IQR):
            raise ValueError("select_top_n_features cannot be greater than the number of elements the DataFrame.")
        if not isinstance(IQR, pd.Series):
            raise TypeError("Input must be a pandas Series.")
        if N is None:
            N = len(IQR)
        return IQR.nlargest(N).index        

    def make_feature_selection_dict(self, df): #$% save IQR for all features?? no doesnt make sense, it is easy to calc on the spot when needed
        """
        Constructs a dictionary of selected features based on their IQR, across different hierarchical levels of the given DataFrame.
    
        Parameters:
        - df (pd.DataFrame): The DataFrame containing the features and hierarchical information.
    
        This method populates the `feature_dict` attribute with the indices of the top N features, selected based on their IQR, for each hierarchical level and category. "All_samples" is for the highest level model across all features. Other features are automatically categorized by the names in the dataframe.
        """
        # special case where we use all features
        IQR, top_n_features_index, selected_rows_index = self._select_features(df, None, None) # None indicated  this special case
        self.selected_feature_dict['Full_model'] = top_n_features_index
        self.sample_dict['Full_model'] = selected_rows_index

        for hierarchy_key in self.ordered_hierarchy_keys[:-1]: # all but last one
            # self.selected_feature_dict[hierarchy_key]={}
            for hierarchy_name in np.unique(df[hierarchy_key]):
                IQR, top_n_features_index, selected_rows_index = self._select_features(df, hierarchy_key, hierarchy_name)
                if IQR is not None: # only create if sub class has more than one possible outcome
                    self.selected_feature_dict[(hierarchy_key, hierarchy_name)] = top_n_features_index
                    self.sample_dict[(hierarchy_key, hierarchy_name)] = selected_rows_index

        # define the target keys for future reference. 
        for key, _ in self.selected_feature_dict.items():
            # for full model use all rows/samples for other models use the name to find the next to the right in the hierarchy order 
            target_key = [self.ordered_hierarchy_keys[0] if key == 'Full_model' else self._next_level(key[0])]
            self.target_key_dict[key] = target_key

    

    def _test_if_only_one_outcome(self, hierarchy_key, hierarchy_name, subset_df):
        """
        Tests if a given hierarchical level and name combination in the subset DataFrame has only one possible outcome in the next hierarchical level.
    
        Parameters:
        - hierarchy_key (str): The current hierarchical level's key.
        - hierarchy_name (str): The name of the current category within the hierarchical level.
        - subset_df (pd.DataFrame): The subset DataFrame filtered for the given hierarchy_key and hierarchy_name.
    
        Returns:
        - (bool, str): A tuple where the first element indicates whether only one outcome exists (True if only one, False otherwise),
          and the second element is a message detailing the result.
        """
        # TEST IF ONLY ONE POSSIBLE OUTCOME. 
        # In some cases a level 'P' hierarchy will have only one possible solution for levle 'P+1' 
        # e.g. Superfamily_code == 'MENING' only has Family_code == 'MENINGI' so we will not build a model for  
        # MENING to predict the Family_code since their is only one. next_hierarchy_key is here becuase we want 
        # to allow for hte edge case of if for example Family_code == 'MENINGI' might have more than one possible 
        # class for example SF(1), F(1), C(2), there the "()" represents how many nodes in a downstream tree. In 
        # this case we would not build a model at SF to predict F, but we WOULD build one at F to predict C. So 
        # next_hierarchy_key represents 'P+1'.
        
        next_hierarchy_key = self.ordered_hierarchy_keys[self.ordered_hierarchy_keys.index(hierarchy_key) + 1] # P+1 index
        next_hierarchy_key = self._next_level(hierarchy_key)
        
        index_to_test = [hierarchy_key, next_hierarchy_key] # P and P+1 index
        unique_subset_df = subset_df[index_to_test].reset_index(drop=True)
        test_only_one_option = (unique_subset_df.nunique() == 1).all() # if true don't build a model, b/c only one option

        return_msg = (
            f'SKIPPING... {hierarchy_key:20} {hierarchy_name:20} '
            f'because it only has one {next_hierarchy_key:20} {unique_subset_df[next_hierarchy_key][0]:20}'
        )

        return test_only_one_option, return_msg
        
    def _test_if_hierarchy_key_in_ordered_hierarchy_keys(self, hierarchy_key):
        """
        Simple test to check if hierarchy_key is in self.ordered_hierarchy_keys
        """
        if hierarchy_key not in self.ordered_hierarchy_keys:
            raise ValueError("hierarchy_key is not in the list of ordered hierarchy keys.")
    
    
    def _next_level(self, hierarchy_key):
        """
        finds the next level based on input (hierarchy_key), e.g. input "Superfamily_code" and it returns "Family_code". More generally, if input is self.ordered_hierarchy_keys[0] it returns self.ordered_hierarchy_keys[1]

        Parameters:
        -hierarchy_key (str): string contained in self.ordered_hierarchy_keys

        Returns:
        - (str): of previous level in self.ordered_hierarchy_keys

        Raises:
        - ValueError: If the input hierarchy_key is not found in self.ordered_hierarchy_keys.
        - IndexError: If the input hierarchy_key is the last element in self.ordered_hierarchy_keys, indicating there is no next level.

        """
        self._test_if_hierarchy_key_in_ordered_hierarchy_keys(hierarchy_key)
        if hierarchy_key == self.ordered_hierarchy_keys[-1]:
            raise IndexError("Input hierarchy_key is the last element in the list; no next level exists.")
            
        next_hierarchy_key = self.ordered_hierarchy_keys[self.ordered_hierarchy_keys.index(hierarchy_key) + 1] # P+1 index
        return next_hierarchy_key

    def _previous_level(self, hierarchy_key):
        """
        finds the previous level based on input (hierarchy_key), e.g. input "Family_code" and it returns "Superfamily_code". More generally, if input is self.ordered_hierarchy_keys[1] it returns self.ordered_hierarchy_keys[0]

        Parameters:
        -hierarchy_key (str): string contained in self.ordered_hierarchy_keys

        Returns:
        - (str): of previous level in self.ordered_hierarchy_keys
        """
        self._test_if_hierarchy_key_in_ordered_hierarchy_keys(hierarchy_key)
        if hierarchy_key == self.ordered_hierarchy_keys[0]:
            raise IndexError("Input hierarchy_key is the first element in the list; no previous level exists.")
            
        previous_hierarchy_key = self.ordered_hierarchy_keys[self.ordered_hierarchy_keys.index(hierarchy_key) - 1] # P-1 index
        return previous_hierarchy_key
        
    def _select_features(self, df, hierarchy_key, hierarchy_name):
        """
        Selects the top N features based on IQR for a specific hierarchy_key and hierarchy_name, or globally if both are None.
    
        Parameters:
        - df (pd.DataFrame): The DataFrame containing the features and hierarchical information.
        - hierarchy_key (str, optional): The hierarchical level's key for which to select features. If None, global feature selection is performed.
        - hierarchy_name (str, optional): The name within the hierarchical level for which to select features.
    
        Returns:
        - (pd.Series, pd.Index): A tuple containing the IQR for the selected features and the indices of the top N features. Returns (None, None) if only one outcome is possible, indicating no need for feature selection.
        """
        if hierarchy_key is None: # special case for when all features (for first model which predicts most major class e.g. super family)
            # selected_rows_index = slice(None)  # This will select all rows
            selected_rows_index = pd.Series([True] * len(df))

            # select rows for this hierarchy 
            subset_df = df.loc[selected_rows_index]

        else:
            selected_rows_index = df[hierarchy_key] == hierarchy_name
            # select rows for this hierarchy 
            subset_df = df.loc[selected_rows_index]
            
            only_one_outcome_test, return_msg  = self._test_if_only_one_outcome(hierarchy_key, hierarchy_name, subset_df)
            if only_one_outcome_test:
                print(return_msg)
                return None, None, None
   
        
        IQR = self._calculate_IQR(subset_df[self.feature_keys]) # get IQR of only the features (ignore the target labels)
        top_n_features_index = self._get_top_n_IQR_index(IQR, self.select_top_n_features) # select to N IQR values
        return IQR, top_n_features_index, selected_rows_index

# %% [markdown]
# ## default models code , RF that matched the R code to the best of my ability

# %%
class default_models():
    @classmethod
    def random_forrest(cls):
        """
        Initializes a RandomForestClassifier with default parameters.
        
        Returns:
            RandomForestClassifier: An instance of RandomForestClassifier with preset parameters.
        """
        rf = RandomForestClassifier(
        n_estimators=500,                                 # matches the R code provided
        criterion='gini',                                 # matches the R code provided, default for classification 
        max_depth=None,                 # no equivalent in the R code provided
        min_samples_split=2,            # no equivalent in the R code provided
        min_samples_leaf=1,                               # no equivalent in the R code provided -- set to 1 so it is irrelivent 
        min_weight_fraction_leaf=0.0,   # no equivalent in the R code provided
        max_features='sqrt',                              # same as "mtry" in R, "sqrt(p)" is default in R 
        max_leaf_nodes=None,                              # same as "maxnode" default in R is NULL eq to None in python
        min_impurity_decrease=0.0,                        # no equivalent in the R, set to 0 to match R (I assume since there is no param for this)
        bootstrap=True,                                   # consistant with R when set to True: when R code "replace" is set to True
        oob_score=False,                                  # for Python it is default accuracy (but can be customized, for R param "err.rate" is kinda the same but not sure which metric
        n_jobs=None,                     # num jobs run in parallel
        random_state=42,                 # equivalent is set.seed -- not set in R code provided 
        verbose=0,                       # 
        warm_start=False,                # no equivalent in the R, default in python is False
        class_weight=None,               # no equivalent in the R, it would be wise to use this for our data
        ccp_alpha=0.0,                   # no equivalent in the R, default in python is 0 
        max_samples=None                 # no equivalent in the R, realted to "sampsize", instead of fraction it is a count and can be stratified per class
        )
        return rf
        
    # @classmethod
    # def k_nearest_neighbors(cls):
        
# default_models.random_forrest()

# %%
class default_models():
    @classmethod
    def random_forrest(cls):
        """
        Initializes a RandomForestClassifier with default parameters.
        
        Returns:
            RandomForestClassifier: An instance of RandomForestClassifier with preset parameters.
        """
        rf = RandomForestClassifier(
        n_estimators=500,                                 # matches the R code provided
        criterion='gini',                                 # matches the R code provided, default for classification 
        max_depth=None,                 # no equivalent in the R code provided
        min_samples_split=2,            # no equivalent in the R code provided
        min_samples_leaf=1,                               # no equivalent in the R code provided -- set to 1 so it is irrelivent 
        min_weight_fraction_leaf=0.0,   # no equivalent in the R code provided
        max_features='sqrt',                              # same as "mtry" in R, "sqrt(p)" is default in R 
        max_leaf_nodes=None,                              # same as "maxnode" default in R is NULL eq to None in python
        min_impurity_decrease=0.0,                        # no equivalent in the R, set to 0 to match R (I assume since there is no param for this)
        bootstrap=True,                                   # consistant with R when set to True: when R code "replace" is set to True
        oob_score=False,                                  # for Python it is default accuracy (but can be customized, for R param "err.rate" is kinda the same but not sure which metric
        n_jobs=None,                     # num jobs run in parallel
        random_state=42,                 # equivalent is set.seed -- not set in R code provided 
        verbose=0,                       # 
        warm_start=False,                # no equivalent in the R, default in python is False
        class_weight=None,               # no equivalent in the R, it would be wise to use this for our data
        ccp_alpha=0.0,                   # no equivalent in the R, default in python is 0 
        max_samples=None                 # no equivalent in the R, realted to "sampsize", instead of fraction it is a count and can be stratified per class
        )
        return rf
        
    # @classmethod
    # def k_nearest_neighbors(cls):
        
default_models.random_forrest()
# Out:
# RandomForestClassifier(n_estimators=500, random_state=42)

# %% [markdown]
# ## class for selecting features based on RF

# %%
class RandomForestFeatureSelection:
    def __init__(self, feature_selection_class, select_top_n_features=10000):
        # Initialize class attributes with copies from `fclass`
        self.selected_feature_dict = copy.deepcopy(feature_selection_class.selected_feature_dict)
        self.sample_dict = copy.deepcopy(feature_selection_class.sample_dict)
        self.ordered_hierarchy_keys = copy.deepcopy(feature_selection_class.ordered_hierarchy_keys)
        self.target_key_dict = copy.deepcopy(feature_selection_class.target_key_dict)

        
        self.select_top_n_features = select_top_n_features
        
        # Initialize dictionaries to store RF models and feature importances
        self.RF_feature_selection_model_dict = {}
        self.RF_feature_importance_dict = {}
        self.RF_selected_features = {}

        self.feature_selection_class = feature_selection_class



    def run_RF_feature_selection(self, df, rf=None):
        """
        Runs feature selection using a RandomForestClassifier.

        Iterates over features and samples, subsets the DataFrame based on these features and samples, 
        and uses a provided or a default RandomForestClassifier to fit the data, updating class 
        attributes with models and feature importances.

        Parameters:
        - df (pd.DataFrame): The DataFrame containing the features and target variables.
        - rf (RandomForestClassifier, optional): A pre-initialized RandomForestClassifier instance. 
                                                  If None, a new classifier with predefined settings is created.

        Returns:
        - tuple: A tuple containing two dictionaries, `RF_feature_selection_model_dict` and `RF_feature_importance_dict`,
                 mapping feature selection scenarios to fitted RandomForestClassifier instances and feature importances, respectively.
        """
        
        for key, feature_col_idx in self.selected_feature_dict.items():
            sample_row_idx = self.sample_dict[key]
            
            target_key = self.target_key_dict[key]
            
            combined_columns = target_key + feature_col_idx.tolist()
            selected_df = df.loc[sample_row_idx, combined_columns]

            if rf is None: #if user doesnt pass in RF model use the default
                rf = default_models.random_forrest()

            X = selected_df[feature_col_idx]  # Feature matrix
            y = selected_df[target_key].iloc[:, 0]  # Target variable, [:, 0] is to flatten it to 1D

            rf.fit(X, y)
            
            self.RF_feature_selection_model_dict[key] = rf
            self.RF_feature_importance_dict[key] = rf.feature_importances_

            # grab top N features 
            selected_features_idx = np.argsort(rf.feature_importances_)[::-1][:self.select_top_n_features] # [::-1] to flip so largest to smallest
            # save them to a dictionary for later
            self.RF_selected_features[key] = [feature_col_idx[f_idx] for f_idx in selected_features_idx]
            

# RFFS = RandomForestFeatureSelection(fclass, select_top_n_features=3)
# RFFS.run_RF_feature_selection(df)

# RF_feature_selection_model_dict, RF_feature_importance_dict = run_RF_feature_selection(df, fclass, rf=None)
# Feature importances from the model
# feature_importances = rf.feature_importances_

# %% [markdown]
# ## CLASS DefaultOptunaStudies

# %%
class DefaultOptunaStudies:
    
    @staticmethod
    def create_cv(cv_folds=3, seed=42):
        """
        Static method to create a StratifiedKFold cross-validator.
        """
        return StratifiedKFold(n_splits=cv_folds, shuffle=True, random_state=seed)

    @staticmethod
    def create_sampler(seed=42):
        """
        Static method to create a sampler with a fixed seed for reproducibility.
        """
        return TPESampler(seed=seed)
        
    @classmethod
    def default_rf_study(cls, X, y, binary_metric_fn='roc_auc', multiclass_metric_fn='roc_auc_ovr', direction='maximize', n_trials=100, cv_folds=3):
        # Utilize the static method to create StratifiedKFold
        cv = cls.create_cv(cv_folds)
        # Utilize the static method to create a sampler with a fixed seed
        sampler = cls.create_sampler()

        # select metric based on binary vs multiclass 
        metric_fn = multiclass_metric_fn if len(np.unique(y))>2 else binary_metric_fn
        

        def objective(trial):
            # Random Forest hyperparameters
            n_estimators = trial.suggest_int('n_estimators', 100, 1000)
            max_depth = trial.suggest_int('max_depth', 2, 128, log=True)
            min_samples_split = trial.suggest_int('min_samples_split', 2, 12)

            # Model initialization with a fixed random_state
            model = RandomForestClassifier(n_estimators=n_estimators, 
                                           max_depth=max_depth,
                                           min_samples_split=min_samples_split, 
                                           criterion='gini',
                                           random_state=42)
            # Cross-validation
            score = cross_val_score(model, X, y, scoring=metric_fn, cv=cv, n_jobs=-1)
            return score.mean()

        study = optuna.create_study(direction=direction, sampler=sampler)
        study.optimize(objective, n_trials=n_trials)
        study.metadata = {'metric_to_optimize':metric_fn,
                         'direction_to_optimize':direction,
                          'n_trials':n_trials,
                          'cv_folds':cv_folds,
                          'is_multi_class':metric_fn==multiclass_metric_fn,
                          'binary_and_multi_class_metrics_list': [binary_metric_fn, multiclass_metric_fn],
                         }
        return study

    @classmethod
    def default_knn_study(cls, X, y, binary_metric_fn='roc_auc', multiclass_metric_fn='roc_auc_ovr', direction='maximize', n_trials=100, cv_folds=3):
        # Utilize the static method to create StratifiedKFold
        cv = cls.create_cv(cv_folds)
        # Utilize the static method to create a sampler with a fixed seed
        sampler = cls.create_sampler()

        # select metric based on binary vs multiclass 
        metric_fn = multiclass_metric_fn if len(np.unique(y))>2 else binary_metric_fn

        def objective(trial):
            # Calculate the valid range of n_neighbors
            max_n_neighbors = cls._get_upper_range_for_k(y, cv_folds)
            n_neighbors = trial.suggest_int('n_neighbors', 2, max_n_neighbors)
            weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
            p = trial.suggest_int('p', 1, 2)

            # Model initialization
            model = KNeighborsClassifier(n_neighbors=n_neighbors, 
                                         weights=weights, 
                                         p=p,
                                         algorithm='auto')
            # Cross-validation
            score = cross_val_score(model, X, y, scoring=metric_fn, cv=cv, n_jobs=-1)
            return score.mean()

        study = optuna.create_study(direction=direction, sampler=sampler)
        study.optimize(objective, n_trials=n_trials)
        study.metadata = {'metric_to_optimize':metric_fn,
                         'direction_to_optimize':direction,
                          'n_trials':n_trials,
                          'cv_folds':cv_folds,
                          'is_multi_class':metric_fn==multiclass_metric_fn,
                          'binary_and_multi_class_metrics_list': [binary_metric_fn, multiclass_metric_fn],
                         }
        return study

    @classmethod
    def _get_upper_range_for_k(cls, y, cv_folds):
        """
        set an upper range for K based on the amount fo data in each training fold. 

        """
        samples_in_cv = np.floor(len(y)/cv_folds)*(cv_folds-1)
        max_k_value = np.floor(np.sqrt(samples_in_cv)*2)
        if samples_in_cv<=4:
            max_k_value = samples_in_cv-1
        return int(max_k_value)

# %% [markdown]
# ## CLASS TrainingData

# %%
# This  needs to be tied into the train all models class this is pointly to be a class as is 
"""
this part int eh train all models class 

# get training data
df_for_training, target_key, selected_features_keys = self.TD.get_training_data(df, global_key)
X, y = df_for_training[selected_features_keys], df_for_training[target_key].iloc[:, 0]

            

needs to be general sucht htat it can be run by itself to get the dat for cisualizing and seeing 
what data was actually traine dthere


"""
class TrainingData():
    def __init__(self, target_dict, selected_feature_dict, sample_dict):
        self.target_dict = target_dict
        self.selected_feature_dict = selected_feature_dict
        self.sample_dict = sample_dict


        
    def _get_combined_training_dataframe(self, df, key):
        
        target_key = self.target_dict[key]
        selected_features_keys = self.selected_feature_dict[key]
        sample_row_idx = self.sample_dict[key]

        combined_columns = target_key + selected_features_keys
        df_for_training = df.loc[sample_row_idx, combined_columns]

        return df_for_training, target_key, selected_features_keys
        
    def get_training_data(self, df, key):
        df_for_training, target_key, selected_features_keys = self._get_combined_training_dataframe(df, key)
        X, y = df_for_training[selected_features_keys], df_for_training[target_key].iloc[:, 0]
        return X, y


# get training data
# df_for_training, target_key, selected_features_keys = self.TD.get_training_data(df, global_key)
# X, y = df_for_training[selected_features_keys], df_for_training[target_key].iloc[:, 0]

# %% [markdown]
# ## CLASS TrainAllModels

# %%
class TrainAllModels():
    def __init__(self, training_data_class):
        """
        Optuna
            model_name (eg full model, etc)
                ML-model type (eg RF KNN)
                    full study
                    best model params
                    best model performance on metric optamized on 
                    target actual -------|
                    prediction (proba) --| both of these are to allow any metric ot be calculated posthoc


        """
        self.TD = training_data_class


        self.optuna = {}
    def model_hyper_parameter_tuning(self):
        """
        optuna tuning here save study best params and best metric each in a seperate dict. 
        
        """
        print('hello model_hyper_parameter_tuning')
    def train_all_models(self, df, binary_metric_fn='roc_auc', multiclass_metric_fn='roc_auc_ovr', direction='maximize', n_trials=100, cv_folds=3):
        

        for global_key, target_key in target_dict.items():
            
            # init keys for saving optuna runs
            self.optuna[global_key] = {'KNN':{},
                                       'RF':{},
                                      }
            
            # get training data
            X, y = self.TD.get_training_data(df, global_key)

            #run optuna studies 
            """
            ideally change the settings of these so that they all have a standard name and key they can be 
            executed regardless of model type

            """
            knn_study = DefaultOptunaStudies.default_knn_study(X, 
                                                               y, 
                                                               binary_metric_fn=binary_metric_fn, 
                                                               multiclass_metric_fn=multiclass_metric_fn, 
                                                               direction=direction, 
                                                               n_trials=n_trials, 
                                                               cv_folds=cv_folds)
            
            rf_study = DefaultOptunaStudies.default_rf_study(X, 
                                                             y, 
                                                             binary_metric_fn=binary_metric_fn, 
                                                             multiclass_metric_fn=multiclass_metric_fn, 
                                                             direction=direction, 
                                                             n_trials=n_trials, 
                                                             cv_folds=cv_folds)

            #save optuna studies 
            self.optuna[global_key]['KNN']['study'] = knn_study
            self.optuna[global_key]['RF']['study'] = rf_study

            # for easy access add these values up front
            for ml_model_key in self.optuna[global_key]:
                d = self.optuna[global_key][ml_model_key]
                d['best_params'] = d['study'].best_params
                d['best_value'] = d['study'].best_value


            

        
        self._get_best_model_key()
            

    def _get_best_model_key(self):
        # get the directions of the metric to optamize. this will be universally the same accross all of the 
        # optuna dictionary, but is set in each model to allow for easier iterating through model types etc. 
        # here we grab the first one which will be the same for every single model. 
        self.best_optuna_model_info = {}
        for gloabl_key, model_groups in self.optuna.items():
        
            direction = model_groups[list(model_groups.keys())[0]]['study'].metadata['direction_to_optimize']
    
            if direction.lower() == 'maximize':
                best_model_key = max(model_groups, key=lambda mod_key: model_groups[mod_key]['study'].best_value)
            elif direction.lower() == 'minimize':
                best_model_key = min(model_groups, key=lambda mod_key: model_groups[mod_key]['study'].best_value)

            # only one model can be the best to ensure this turn all to False then set it . 
            for mod_key in model_groups:
                model_groups[mod_key]['IS_BEST_MODEL'] = False
            model_groups[best_model_key]['IS_BEST_MODEL'] = True


            # this is optional but is a easy way to access some of the importnat information for the selected best 
            # model based on Optuna. all this is accessible in the Optuna dict but this is organzied as a dict to 
            # be used 99% time since we only care about the best model unless digging int it for issues later. 
            best_model = model_groups[best_model_key]
            
            self.best_optuna_model_info[gloabl_key] = {
                'model_key':                best_model_key,  # Assuming best_model_key is the key for the best model
                'params':                   best_model['best_params'],
                'metric_performance':       best_model['best_value'],
                'is_multi_class':           best_model['study'].metadata['is_multi_class'],
                'n_trials':                 best_model['study'].metadata['n_trials'],
                'cv_folds':                 best_model['study'].metadata['cv_folds'],
                'metric_to_optimize':       best_model['study'].metadata['metric_to_optimize'],
                'direction_to_optimize':    best_model['study'].metadata['direction_to_optimize'],
            }

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# # start

# %% [markdown]
# ## load data

# %%
# Save the directory as a variable
data_dir = "/Users/pmaire/Documents/methyl_chla_data/small_data/integrated_cohort_betas_withannotation_small.feather"

# Load the data into pandas
df = pd.read_feather(data_dir)
df
# Out:
#     Superfamily_code Family_code Class_v12_code  cg00212031  cg00650640  \
# 0              EMBRY          MB  MB_SHH_CHL_AD    0.060056    0.174830
# 1              EMBRY          MB     MB_SHH_INF    0.105263    0.000000
# 2              EMBRY          MB          MB_G3    0.066739    0.000000
# 3              EMBRY          MB          MB_G4    0.531080    0.063247
# 4              EMBRY          MB          MB_G3    0.043150    0.024174
# ..               ...         ...            ...         ...         ...
# 268            CNTRL  CNTL_BRAIN  CTRL_HYPOTHAL    0.058519    0.179859
# 269            CNTRL  CNTL_BRAIN  CTRL_HYPOTHAL    0.033036    0.070123
# 270           SELLAR      PIT_AD      PITAD_TSH    0.066259    0.181447
# 271           SELLAR      PIT_AD      PITAD_TSH    0.310545    0.025473
# 272           SELLAR      PIT_AD      PITAD_TSH    0.260058    0.149319
#
#      cg02010442  cg03272642  cg04413754  cg05467600  cg06443675  ...  \
# 0      0.069681    0.014120    0.323789    0.001262    0.051747  ...
# 1      0.022624    0.038429    0.364521    0.014286    0.103865  ...
# 2      0.084729    0.017830    0.314324    0.011889    0.036709  ...
# 3      0.005567    0.563444    0.217828    0.049134    0.430767  ...
# 4      0.016813    0.047187    0.339644    0.010687    0.100941  ...
# ..          ...         ...         ...         ...         ...  ...
# 268    0.036976    0.031447    0.213456    0.000087    0.029990  ...
# 269    0.038106    0.024388    0.284708    0.000090    0.085306  ...
# 270    0.052543    0.034760    0.302180    0.000118    0.080423  ...
# 271    0.064488    0.079658    0.226034    0.093056    0.068528  ...
# 272    0.421268    0.269908    0.254474    0.073547    0.205283  ...
#
#      cg20787201  cg21432763  cg22117819  cg22764925  cg23568913  cg24300216  \
# 0      0.441887    0.777161    0.615736    0.107996    0.051777    0.867771
# 1      0.542503    0.805603    0.405675    0.140824    0.031228    0.905519
# 2      0.834260    0.770924    0.325451    0.114108    0.035967    0.909144
# 3      0.754954    0.770129    0.084212    0.079013    0.000000    0.840391
# 4      0.841666    0.298231    0.355325    0.179955    0.034624    0.887187
# ..          ...         ...         ...         ...         ...         ...
# 268    0.858359    0.717412    0.655881    0.401737    0.053558    0.922711
# 269    0.851719    0.751161    0.631748    0.426520    0.057775    0.916897
# 270    0.753122    0.438892    0.472267    0.185292    0.049762    0.529293
# 271    0.824229    0.389241    0.655720    0.191878    0.038382    0.800685
# 272    0.863978    0.589968    0.786672    0.250783    0.045690    0.954363
#
#      cg25246692  cg25947555  cg26730347  cg27454842
# 0      0.144181    0.083772    0.346352    0.639290
# 1      0.107303    0.054950    0.229818    0.557485
# 2      0.128023    0.053382    0.626938    0.427096
# 3      0.070619    0.026671    0.222368    0.451694
# 4      0.087058    0.050882    0.075250    0.266236
# ..          ...         ...         ...         ...
# 268    0.324555    0.093040    0.590416    0.531673
# 269    0.308583    0.090510    0.495698    0.492520
# 270    0.456113    0.059071    0.839434    0.860006
# 271    0.353596    0.092287    0.534643    0.655044
# 272    0.132010    0.036515    0.353978    0.893873
#
# [273 rows x 3701 columns]

# %% [markdown]
# ## keep track of keys, the user will be responsible for this

# %%
class Keys:
    targets = []
"""THESE MUST BE PUT IN THE CORRECT ORDER HERE SOME DESIGN DECISION MUST BE MADE"""
# Keys.targets = list(df.keys())[:3] ## we explicitly set targets to prevent any indexing issues 
Keys.targets = ['Superfamily_code', 'Family_code', 'Class_v12_code']
print('Target keys ... ' + ', '.join(Keys.targets))

Keys.features = [key for key in df.keys() if key not in Keys.targets]
print('Feature keys are... everything else')
# Out:
# Target keys ... Superfamily_code, Family_code, Class_v12_code
# Feature keys are... everything else

# %% [markdown]
# ## init the hierarchy structure and select features based on the IQR

# %%
hierarchy_keys, hierarchy_levels, feature_keys, select_top_n_features = Keys.targets, [0, 1, 2], Keys.features, 10

fclass = feature_selection(hierarchy_keys, hierarchy_levels, feature_keys, select_top_n_features)

fclass.make_feature_selection_dict(df)
# Out:
# SKIPPING... Superfamily_code     CHOROID_PLEX         because it only has one Family_code          PLEXUS
# SKIPPING... Superfamily_code     MENING               because it only has one Family_code          MENINGI
# SKIPPING... Superfamily_code     OLFACT               because it only has one Family_code          ESTHESIO
# SKIPPING... Family_code          CIRC_MENING_MELANO   because it only has one Class_v12_code       MELN
# SKIPPING... Family_code          CRAN_PARASPINAL      because it only has one Class_v12_code       CAUDEQU_NET
# SKIPPING... Family_code          INFLAM_ENV           because it only has one Class_v12_code       INFLAM_ENV
# SKIPPING... Family_code          LYMPH                because it only has one Class_v12_code       DLBCL
# SKIPPING... Family_code          MELANOCYTIC          because it only has one Class_v12_code       MET_MEL
# SKIPPING... Family_code          MELANO_NERVE_SHEETH  because it only has one Class_v12_code       MMNST
# SKIPPING... Family_code          MENINGI              because it only has one Class_v12_code       MNG
# SKIPPING... Family_code          MISC_RARE_LYMPH      because it only has one Class_v12_code       PLASMACYT
# SKIPPING... Family_code          NORM_PINEAL          because it only has one Class_v12_code       CTRL_PIN
# SKIPPING... Family_code          NOTOCHRD             because it only has one Class_v12_code       CHORDM
# SKIPPING... Family_code          PINEAL               because it only has one Class_v12_code       PPPTID
# SKIPPING... Family_code          PITUI                because it only has one Class_v12_code       PITUI
# SKIPPING... Family_code          RETBL                because it only has one Class_v12_code       RB
# SKIPPING... Family_code          SCHWANN              because it only has one Class_v12_code       SCHW
# SKIPPING... Family_code          ped_LGG              because it only has one Class_v12_code       AG_MYB

# %%
info_dict.vis(fclass.selected_feature_dict)
# Out:
# ├── Full_model                                  : type: Index, len: 10 Index(['cg04209913', 'cg24981593', 'cg10623600', 'cg01207684', 'cg25286482',
#        'cg06132069', 'c...
# ├── ('Superfamily_code', 'CNTRL')               : type: Index, len: 10 Index(['cg10193711', 'cg11854392', 'cg03683087', 'cg05876564', 'cg04209913',
#        'cg26348348', 'c...
# ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: Index, len: 10 Index(['cg22972519', 'cg27436952', 'cg21376454', 'cg16175703', 'cg24665113',
#        'cg26703880', 'c...
# ├── ('Superfamily_code', 'EMBRY')               : type: Index, len: 10 Index(['cg11740348', 'cg24164564', 'cg03909863', 'cg25957967', 'cg16410524',
#        'cg04209913', 'c...
# ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: Index, len: 10 Index(['cg17090968', 'cg04209913', 'cg09799983', 'cg03350900', 'cg11740348',
#        'cg07060794', 'c...
# ├── ('Superfamily_code', 'HEMA')                : type: Index, len: 10 Index(['cg26348348', 'cg24344662', 'cg02081701', 'cg20992181', 'cg04737131',
#        'cg06609197', 'c...
# ├── ('Superfamily_code', 'MELANO')              : type: Index, len: 10 Index(['cg09799983', 'cg25916282', 'cg15532640', 'cg03078363', 'cg25506747',
#        'cg21932416', 'c...
# ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: Index, len: 10 Index(['cg26299044', 'cg10623600', 'cg12694372', 'cg05658107', 'cg01207684',
#        'cg17645677', 'c...
# ├── ('Superfamily_code', 'PIN_RET')             : type: Index, len: 10 Index(['cg21185289', 'cg15188398', 'cg09053081', 'cg04209913', 'cg15157241',
#        'cg24164564', 'c...
# ├── ('Superfamily_code', 'SELLAR')              : type: Index, len: 10 Index(['cg06132069', 'cg25406442', 'cg15337521', 'cg09388540', 'cg12511749',
#        'cg12733396', 'c...
# ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: Index, len: 10 Index(['cg17090968', 'cg12676702', 'cg21932416', 'cg04209913', 'cg10950297',
#        'cg05916707', 'c...
# ├── ('Family_code', 'CNTL_BRAIN')               : type: Index, len: 10 Index(['cg27622679', 'cg12819548', 'cg21550442', 'cg08785724', 'cg22630748',
#        'cg05393025', 'c...
# ├── ('Family_code', 'CRANIO')                   : type: Index, len: 10 Index(['cg10193711', 'cg16759416', 'cg24164564', 'cg19889066', 'cg16206341',
#        'cg14321539', 'c...
# ├── ('Family_code', 'CTRL_TME')                 : type: Index, len: 10 Index(['cg10623600', 'cg22193385', 'cg04209913', 'cg00698771', 'cg10193711',
#        'cg03683087', 'c...
# ├── ('Family_code', 'EPENDYM')                  : type: Index, len: 10 Index(['cg26348348', 'cg12434898', 'cg02928365', 'cg12456011', 'cg24412662',
#        'cg03386869', 'c...
# ├── ('Family_code', 'ESTHESIO')                 : type: Index, len: 10 Index(['cg25957967', 'cg23484159', 'cg26730347', 'cg07586489', 'cg15633056',
#        'cg07307388', 'c...
# ├── ('Family_code', 'GLIONEUR_NEUR')            : type: Index, len: 10 Index(['cg03386869', 'cg16759416', 'cg15337521', 'cg27508055', 'cg17227257',
#        'cg11289677', 'c...
# ├── ('Family_code', 'HGG')                      : type: Index, len: 10 Index(['cg24164564', 'cg09053081', 'cg09799983', 'cg06480736', 'cg00591844',
#        'cg14279121', 'c...
# ├── ('Family_code', 'MB')                       : type: Index, len: 10 Index(['cg04209913', 'cg24164564', 'cg25957967', 'cg15837233', 'cg23598080',
#        'cg09799983', 'c...
# ├── ('Family_code', 'OTHER_EMBRY')              : type: Index, len: 10 Index(['cg01207684', 'cg17904575', 'cg17090968', 'cg23638042', 'cg18409732',
#        'cg24164564', 'c...
# ├── ('Family_code', 'PAP_PINEAL')               : type: Index, len: 10 Index(['cg20895877', 'cg04209913', 'cg16449012', 'cg09799983', 'cg16406892',
#        'cg14473743', 'c...
# ├── ('Family_code', 'PINEOBLAST')               : type: Index, len: 10 Index(['cg00698771', 'cg18947175', 'cg25778892', 'cg12173150', 'cg01510696',
#        'cg23933095', 'c...
# ├── ('Family_code', 'PIT_AD')                   : type: Index, len: 10 Index(['cg22807732', 'cg03625415', 'cg25406442', 'cg13002222', 'cg09388540',
#        'cg26380106', 'c...
# ├── ('Family_code', 'PLEXUS')                   : type: Index, len: 10 Index(['cg07795402', 'cg10623600', 'cg00650640', 'cg21185289', 'cg24996154',
#        'cg09053081', 'c...
# ├── ('Family_code', 'SFT')                      : type: Index, len: 10 Index(['cg09798202', 'cg22974630', 'cg08684879', 'cg03669394', 'cg24106661',
#        'cg09884146', 'c...
# └── ('Family_code', 'UNCERT_DIFF')              : type: Index, len: 10 Index(['cg00698771', 'cg09814029', 'cg00590173', 'cg03078363', 'cg11165254',
#        'cg17090968', 'c...

# %% [markdown]
# ## run the RandomForestFeatureSelection calss to select features.

# %%
RFFS = RandomForestFeatureSelection(fclass, select_top_n_features=3)
RFFS.run_RF_feature_selection(df)

# %% [markdown]
# ## Run train all model invoking TrainingData class as a helper

# %%
target_dict, selected_feature_dict, sample_dict = fclass.target_key_dict, RFFS.RF_selected_features, fclass.sample_dict
training_data_class = TrainingData(target_dict, selected_feature_dict, sample_dict)

# %%
TAM = TrainAllModels(training_data_class)
TAM.train_all_models(df, binary_metric_fn='roc_auc', multiclass_metric_fn='roc_auc_ovr', direction='maximize', n_trials=10, cv_folds=3)
# Out:
# [I 2024-04-08 15:36:45,703] A new study created in memory with name: no-name-bb022551-32bf-4203-a807-bfa789e7f03e
# [I 2024-04-08 15:36:46,741] Trial 0 finished with value: 0.8150036014831357 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8150036014831357.
# [I 2024-04-08 15:36:47,179] Trial 1 finished with value: 0.7670171888202421 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8150036014831357.
# [I 2024-04-08 15:36:47,195] Trial 2 finished with value: 0.8249904200513672 and parameters: {'n_neighbors': 17, 'weights': 'uniform', 'p': 2}. Best is trial 2 with value: 0.8249904200513672.
# [I 2024-04-08 15:36:47,209] Trial 3 finished with value: 0.8542788926843987 and parameters: {'n_neighbors': 22, 'weights': 'uniform', 'p': 1}. Best is trial 3 with value: 0.8542788926843987.
# [I 2024-04-08 15:36:47,619] Trial 4 finished with value: 0.8108988650211725 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'p': 1}. Best is trial 3 with value: 0.8542788926843987.
# [I 2024-04-08 15:36:47,634] Trial 5 finished with value: 0.844492493214677 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'p': 1}. Best is trial 3 with value: 0.8542788926843987.
# [I 2024-04-08 15:36:48,076] Trial 6 finished with value: 0.8151282645145067 and parameters: {'n_neighbors': 13, 'weights': 'uniform', 'p': 2}. Best is trial 3 with value: 0.8542788926843987.
# [I 2024-04-08 15:36:48,092] Trial 7 finished with value: 0.8373847617705005 and parameters: {'n_neighbors': 16, 'weights': 'distance', 'p': 1}. Best is trial 3 with value: 0.8542788926843987.
# [I 2024-04-08 15:36:48,530] Trial 8 finished with value: 0.7072807215358035 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 2}. Best is trial 3 with value: 0.8542788926843987.
# [I 2024-04-08 15:36:48,544] Trial 9 finished with value: 0.8140370509860579 and parameters: {'n_neighbors': 9, 'weights': 'distance', 'p': 1}. Best is trial 3 with value: 0.8542788926843987.
# [I 2024-04-08 15:36:48,544] A new study created in memory with name: no-name-ea9b4a98-49f1-4cb6-bb80-8cbecd770d0a
# [I 2024-04-08 15:36:48,780] Trial 0 finished with value: 0.8787181159324522 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.8787181159324522.
# [I 2024-04-08 15:36:49,472] Trial 1 finished with value: 0.8751445327871262 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 0 with value: 0.8787181159324522.
# [I 2024-04-08 15:36:49,575] Trial 2 finished with value: 0.8717663390838886 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 0 with value: 0.8787181159324522.
# [I 2024-04-08 15:36:49,897] Trial 3 finished with value: 0.864344162068566 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 0 with value: 0.8787181159324522.
# [I 2024-04-08 15:36:50,269] Trial 4 finished with value: 0.8796031427326194 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 4 with value: 0.8796031427326194.
# [I 2024-04-08 15:36:50,397] Trial 5 finished with value: 0.8783684263388181 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 4 with value: 0.8796031427326194.
# [I 2024-04-08 15:36:50,620] Trial 6 finished with value: 0.8756091640803185 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 4 with value: 0.8796031427326194.
# [I 2024-04-08 15:36:50,732] Trial 7 finished with value: 0.8767461127460227 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 4 with value: 0.8796031427326194.
# [I 2024-04-08 15:36:50,973] Trial 8 finished with value: 0.8755590577783533 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 4 with value: 0.8796031427326194.
# [I 2024-04-08 15:36:51,239] Trial 9 finished with value: 0.8670995043917301 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 4 with value: 0.8796031427326194.
# [I 2024-04-08 15:36:51,241] A new study created in memory with name: no-name-3b051aac-a9ac-4153-9bd9-932617b85406
# [I 2024-04-08 15:36:51,256] Trial 0 finished with value: 0.9642857142857144 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9642857142857144.
# [I 2024-04-08 15:36:51,270] Trial 1 finished with value: 0.9821428571428572 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 1 with value: 0.9821428571428572.
# [I 2024-04-08 15:36:51,285] Trial 2 finished with value: 0.9290178571428571 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 2}. Best is trial 1 with value: 0.9821428571428572.
# [I 2024-04-08 15:36:51,301] Trial 3 finished with value: 0.9108630952380952 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 1}. Best is trial 1 with value: 0.9821428571428572.
# [I 2024-04-08 15:36:51,316] Trial 4 finished with value: 0.9642857142857143 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1}. Best is trial 1 with value: 0.9821428571428572.
# [I 2024-04-08 15:36:51,330] Trial 5 finished with value: 0.9940476190476191 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9940476190476191.
# [I 2024-04-08 15:36:51,345] Trial 6 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 0.9940476190476191.
# [I 2024-04-08 15:36:51,359] Trial 7 finished with value: 0.9940476190476191 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9940476190476191.
# [I 2024-04-08 15:36:51,374] Trial 8 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 8 with value: 1.0.
# [I 2024-04-08 15:36:51,389] Trial 9 finished with value: 1.0 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 8 with value: 1.0.
# [I 2024-04-08 15:36:51,389] A new study created in memory with name: no-name-7628b2ac-8894-495c-992c-f408055d5d0c
# [I 2024-04-08 15:36:51,564] Trial 0 finished with value: 0.9422619047619047 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.9422619047619047.
# [I 2024-04-08 15:36:51,814] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:51,879] Trial 2 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:52,165] Trial 3 finished with value: 0.918452380952381 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:52,493] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:52,608] Trial 5 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:52,809] Trial 6 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:52,912] Trial 7 finished with value: 0.9821428571428572 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:53,136] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:53,361] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:36:53,362] A new study created in memory with name: no-name-74c45f8e-f515-4c40-98a5-4312f8300107
# [I 2024-04-08 15:36:53,402] Trial 0 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,415] Trial 1 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,440] Trial 2 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,455] Trial 3 finished with value: 0.7777777777777778 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,888] Trial 4 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,916] Trial 5 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,930] Trial 6 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,945] Trial 7 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,959] Trial 8 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,975] Trial 9 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:36:53,975] A new study created in memory with name: no-name-112b1538-f986-4fbc-a0b9-45bc77f503b5
# [I 2024-04-08 15:36:54,170] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:36:54,829] Trial 1 finished with value: 0.9444444444444445 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:54,901] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:55,187] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:55,513] Trial 4 finished with value: 0.9444444444444445 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:55,868] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:56,067] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:56,167] Trial 7 finished with value: 0.888888888888889 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:56,364] Trial 8 finished with value: 0.9444444444444445 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 0.9444444444444445.
# [I 2024-04-08 15:36:56,591] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 9 with value: 1.0.
# [I 2024-04-08 15:36:56,592] A new study created in memory with name: no-name-be84b5ca-da87-4b79-b874-f816bb034e5f
# [I 2024-04-08 15:36:56,991] Trial 0 finished with value: 0.9777777777777779 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9777777777777779.
# [I 2024-04-08 15:36:57,004] Trial 1 finished with value: 0.861111111111111 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9777777777777779.
# [I 2024-04-08 15:36:57,017] Trial 2 finished with value: 0.9666666666666667 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9777777777777779.
# [I 2024-04-08 15:36:57,031] Trial 3 finished with value: 0.9722222222222222 and parameters: {'n_neighbors': 8, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9777777777777779.
# [I 2024-04-08 15:36:57,045] Trial 4 finished with value: 0.9666666666666667 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9777777777777779.
# [I 2024-04-08 15:36:57,058] Trial 5 finished with value: 0.9888888888888889 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:57,070] Trial 6 finished with value: 0.9833333333333334 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:57,082] Trial 7 finished with value: 0.9888888888888889 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:57,097] Trial 8 finished with value: 0.861111111111111 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 5 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:57,111] Trial 9 finished with value: 0.9777777777777779 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:57,112] A new study created in memory with name: no-name-50b5c2c9-86ba-4851-992c-94703e41cecd
# [I 2024-04-08 15:36:57,305] Trial 0 finished with value: 0.9777777777777779 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.9777777777777779.
# [I 2024-04-08 15:36:57,564] Trial 1 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:57,640] Trial 2 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:57,926] Trial 3 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:58,261] Trial 4 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:58,375] Trial 5 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:58,576] Trial 6 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:58,676] Trial 7 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:58,902] Trial 8 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:59,139] Trial 9 finished with value: 0.9888888888888889 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 0.9888888888888889.
# [I 2024-04-08 15:36:59,141] A new study created in memory with name: no-name-72c7f5f3-4705-4a42-987e-e185207d3e0e
# [I 2024-04-08 15:36:59,155] Trial 0 finished with value: 0.831135194307608 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.831135194307608.
# [I 2024-04-08 15:36:59,169] Trial 1 finished with value: 0.7748386243386243 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.831135194307608.
# [I 2024-04-08 15:36:59,184] Trial 2 finished with value: 0.823626254333151 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.831135194307608.
# [I 2024-04-08 15:36:59,198] Trial 3 finished with value: 0.8423029556650247 and parameters: {'n_neighbors': 15, 'weights': 'uniform', 'p': 1}. Best is trial 3 with value: 0.8423029556650247.
# [I 2024-04-08 15:36:59,213] Trial 4 finished with value: 0.82772568874293 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 1}. Best is trial 3 with value: 0.8423029556650247.
# [I 2024-04-08 15:36:59,227] Trial 5 finished with value: 0.8482340813720124 and parameters: {'n_neighbors': 11, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.8482340813720124.
# [I 2024-04-08 15:36:59,241] Trial 6 finished with value: 0.8385020069330414 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 0.8482340813720124.
# [I 2024-04-08 15:36:59,256] Trial 7 finished with value: 0.8482340813720124 and parameters: {'n_neighbors': 11, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.8482340813720124.
# [I 2024-04-08 15:36:59,270] Trial 8 finished with value: 0.7817299762817004 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 2}. Best is trial 5 with value: 0.8482340813720124.
# [I 2024-04-08 15:36:59,284] Trial 9 finished with value: 0.8367770479839445 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.8482340813720124.
# [I 2024-04-08 15:36:59,285] A new study created in memory with name: no-name-39cf0042-d8f3-44e1-bec1-be0ed7765fb6
# [I 2024-04-08 15:36:59,494] Trial 0 finished with value: 0.8547162926473272 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:36:59,768] Trial 1 finished with value: 0.8460870279146141 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:36:59,843] Trial 2 finished with value: 0.854703338806787 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:00,152] Trial 3 finished with value: 0.8423727422003283 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:00,485] Trial 4 finished with value: 0.8521660280970625 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:00,599] Trial 5 finished with value: 0.8438078817733988 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:00,807] Trial 6 finished with value: 0.852031746031746 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:00,909] Trial 7 finished with value: 0.8499633278598796 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:01,128] Trial 8 finished with value: 0.8531346469622331 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:01,364] Trial 9 finished with value: 0.8530250866630177 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 0 with value: 0.8547162926473272.
# [I 2024-04-08 15:37:01,366] A new study created in memory with name: no-name-a59c6dd4-6848-4203-b810-1f9a3da71bac
# [I 2024-04-08 15:37:01,392] Trial 0 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,405] Trial 1 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,417] Trial 2 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,430] Trial 3 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,445] Trial 4 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,458] Trial 5 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,472] Trial 6 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,485] Trial 7 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,499] Trial 8 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,514] Trial 9 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:01,514] A new study created in memory with name: no-name-41f0b617-c014-4307-8357-af9124f70ff0
# [I 2024-04-08 15:37:01,690] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:37:01,938] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:02,003] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:02,290] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:02,628] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:02,742] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:02,942] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:03,042] Trial 7 finished with value: 0.5 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:03,250] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:03,473] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:03,475] A new study created in memory with name: no-name-e31a58f0-a431-498a-8f4b-c6d9de54bc46
# [I 2024-04-08 15:37:03,500] Trial 0 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8333333333333334.
# [I 2024-04-08 15:37:03,527] Trial 1 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8333333333333334.
# [I 2024-04-08 15:37:03,541] Trial 2 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8333333333333334.
# [I 2024-04-08 15:37:03,555] Trial 3 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.8333333333333334.
# [I 2024-04-08 15:37:03,569] Trial 4 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.8333333333333334.
# [I 2024-04-08 15:37:03,583] Trial 5 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:03,596] Trial 6 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:03,610] Trial 7 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:03,624] Trial 8 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:03,637] Trial 9 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:03,638] A new study created in memory with name: no-name-3b30258a-7b21-4452-a0bd-bf06559f1ee6
# [I 2024-04-08 15:37:03,818] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:37:04,066] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:04,128] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:04,413] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:04,735] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:04,849] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:05,047] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:05,148] Trial 7 finished with value: 0.5 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:05,347] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:05,573] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:05,575] A new study created in memory with name: no-name-b008c9cd-1f97-4884-946e-f674e3845af5
# [I 2024-04-08 15:37:05,590] Trial 0 finished with value: 0.8796296296296297 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8796296296296297.
# [I 2024-04-08 15:37:05,604] Trial 1 finished with value: 0.8796296296296297 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8796296296296297.
# [I 2024-04-08 15:37:05,618] Trial 2 finished with value: 0.9398148148148149 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,633] Trial 3 finished with value: 0.8657407407407408 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 1}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,647] Trial 4 finished with value: 0.9259259259259259 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,674] Trial 5 finished with value: 0.9074074074074074 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,689] Trial 6 finished with value: 0.8333333333333334 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,703] Trial 7 finished with value: 0.9259259259259259 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,717] Trial 8 finished with value: 0.8796296296296297 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,730] Trial 9 finished with value: 0.9259259259259259 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 2 with value: 0.9398148148148149.
# [I 2024-04-08 15:37:05,731] A new study created in memory with name: no-name-c1e51130-529c-45ce-ae77-148aa9c910a0
# [I 2024-04-08 15:37:05,901] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:37:06,150] Trial 1 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:06,215] Trial 2 finished with value: 0.8425925925925927 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:06,501] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:06,825] Trial 4 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:06,940] Trial 5 finished with value: 0.8425925925925927 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:07,139] Trial 6 finished with value: 0.8472222222222223 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:07,236] Trial 7 finished with value: 0.851851851851852 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:07,436] Trial 8 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:07,662] Trial 9 finished with value: 0.888888888888889 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:07,664] A new study created in memory with name: no-name-365eb700-248f-4572-91cb-bf3dd74f0813
# [I 2024-04-08 15:37:07,678] Trial 0 finished with value: 0.8666666666666666 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8666666666666666.
# [I 2024-04-08 15:37:07,692] Trial 1 finished with value: 0.8645833333333334 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8666666666666666.
# [I 2024-04-08 15:37:07,706] Trial 2 finished with value: 0.8010416666666668 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8666666666666666.
# [I 2024-04-08 15:37:07,721] Trial 3 finished with value: 0.7989583333333332 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.8666666666666666.
# [I 2024-04-08 15:37:07,735] Trial 4 finished with value: 0.8666666666666666 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.8666666666666666.
# [I 2024-04-08 15:37:07,747] Trial 5 finished with value: 0.9354166666666667 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:07,761] Trial 6 finished with value: 0.9 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:07,774] Trial 7 finished with value: 0.9458333333333333 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 7 with value: 0.9458333333333333.
# [I 2024-04-08 15:37:07,788] Trial 8 finished with value: 0.8729166666666667 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 7 with value: 0.9458333333333333.
# [I 2024-04-08 15:37:07,803] Trial 9 finished with value: 0.8854166666666666 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 7 with value: 0.9458333333333333.
# [I 2024-04-08 15:37:07,804] A new study created in memory with name: no-name-cfd1ea20-c8a5-45ee-9f5a-821c54dd6129
# [I 2024-04-08 15:37:07,975] Trial 0 finished with value: 0.896875 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.896875.
# [I 2024-04-08 15:37:08,222] Trial 1 finished with value: 0.9354166666666667 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:08,294] Trial 2 finished with value: 0.8916666666666666 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:08,578] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:08,911] Trial 4 finished with value: 0.9249999999999999 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:09,020] Trial 5 finished with value: 0.9187500000000001 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:09,217] Trial 6 finished with value: 0.8583333333333334 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:09,317] Trial 7 finished with value: 0.9354166666666667 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:09,517] Trial 8 finished with value: 0.9354166666666667 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 0.9354166666666667.
# [I 2024-04-08 15:37:09,741] Trial 9 finished with value: 0.9458333333333333 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 9 with value: 0.9458333333333333.
# [I 2024-04-08 15:37:09,743] A new study created in memory with name: no-name-7b2e5cd0-9c4c-442b-bfd6-ef4efcba6794
# [I 2024-04-08 15:37:09,758] Trial 0 finished with value: 0.9085648148148149 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9085648148148149.
# [I 2024-04-08 15:37:09,770] Trial 1 finished with value: 0.8989197530864198 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9085648148148149.
# [I 2024-04-08 15:37:09,784] Trial 2 finished with value: 0.9421296296296297 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 2}. Best is trial 2 with value: 0.9421296296296297.
# [I 2024-04-08 15:37:09,798] Trial 3 finished with value: 0.9421296296296297 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 1}. Best is trial 2 with value: 0.9421296296296297.
# [I 2024-04-08 15:37:09,812] Trial 4 finished with value: 0.91820987654321 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1}. Best is trial 2 with value: 0.9421296296296297.
# [I 2024-04-08 15:37:09,826] Trial 5 finished with value: 0.9421296296296297 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 2 with value: 0.9421296296296297.
# [I 2024-04-08 15:37:09,840] Trial 6 finished with value: 0.9517746913580248 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 6 with value: 0.9517746913580248.
# [I 2024-04-08 15:37:09,853] Trial 7 finished with value: 0.9421296296296297 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 6 with value: 0.9517746913580248.
# [I 2024-04-08 15:37:09,867] Trial 8 finished with value: 0.8028549382716049 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 6 with value: 0.9517746913580248.
# [I 2024-04-08 15:37:09,882] Trial 9 finished with value: 0.91820987654321 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 6 with value: 0.9517746913580248.
# [I 2024-04-08 15:37:09,882] A new study created in memory with name: no-name-12b27e27-cefb-40ca-bbf9-7822dca3f071
# [I 2024-04-08 15:37:10,058] Trial 0 finished with value: 0.9544753086419754 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.9544753086419754.
# [I 2024-04-08 15:37:10,305] Trial 1 finished with value: 0.98070987654321 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:10,380] Trial 2 finished with value: 0.9641203703703703 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:10,668] Trial 3 finished with value: 0.9544753086419754 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:10,991] Trial 4 finished with value: 0.98070987654321 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:11,106] Trial 5 finished with value: 0.9641203703703703 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:11,306] Trial 6 finished with value: 0.9641203703703703 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:11,406] Trial 7 finished with value: 0.98070987654321 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:11,606] Trial 8 finished with value: 0.98070987654321 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:11,829] Trial 9 finished with value: 0.9614197530864198 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 0.98070987654321.
# [I 2024-04-08 15:37:11,831] A new study created in memory with name: no-name-91729662-155a-45d3-a9d8-6528b02847d4
# [I 2024-04-08 15:37:11,846] Trial 0 finished with value: 0.8958333333333334 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8958333333333334.
# [I 2024-04-08 15:37:11,860] Trial 1 finished with value: 0.8630952380952381 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8958333333333334.
# [I 2024-04-08 15:37:11,874] Trial 2 finished with value: 0.8630952380952381 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.8958333333333334.
# [I 2024-04-08 15:37:11,889] Trial 3 finished with value: 0.7886904761904762 and parameters: {'n_neighbors': 7, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.8958333333333334.
# [I 2024-04-08 15:37:11,903] Trial 4 finished with value: 0.9017857142857144 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1}. Best is trial 4 with value: 0.9017857142857144.
# [I 2024-04-08 15:37:11,918] Trial 5 finished with value: 0.9196428571428572 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9196428571428572.
# [I 2024-04-08 15:37:11,932] Trial 6 finished with value: 0.8779761904761906 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 0.9196428571428572.
# [I 2024-04-08 15:37:11,944] Trial 7 finished with value: 0.9196428571428572 and parameters: {'n_neighbors': 6, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9196428571428572.
# [I 2024-04-08 15:37:11,958] Trial 8 finished with value: 0.7767857142857144 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 5 with value: 0.9196428571428572.
# [I 2024-04-08 15:37:11,972] Trial 9 finished with value: 0.9196428571428572 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 0.9196428571428572.
# [I 2024-04-08 15:37:11,973] A new study created in memory with name: no-name-49a910ab-0dde-4cc5-84b0-d3c22ae7a56d
# [I 2024-04-08 15:37:12,183] Trial 0 finished with value: 0.8928571428571429 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.8928571428571429.
# [I 2024-04-08 15:37:12,432] Trial 1 finished with value: 0.8988095238095237 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.8988095238095237.
# [I 2024-04-08 15:37:12,510] Trial 2 finished with value: 0.9107142857142857 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 2 with value: 0.9107142857142857.
# [I 2024-04-08 15:37:12,793] Trial 3 finished with value: 0.8988095238095238 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 2 with value: 0.9107142857142857.
# [I 2024-04-08 15:37:13,127] Trial 4 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:13,239] Trial 5 finished with value: 0.8988095238095238 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:13,437] Trial 6 finished with value: 0.8988095238095237 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:13,539] Trial 7 finished with value: 0.9047619047619048 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:13,742] Trial 8 finished with value: 0.9166666666666666 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:13,967] Trial 9 finished with value: 0.9107142857142856 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 4 with value: 0.9166666666666666.
# [I 2024-04-08 15:37:13,968] A new study created in memory with name: no-name-b9519166-190d-43be-ba7b-5d815dd092fb
# [I 2024-04-08 15:37:13,983] Trial 0 finished with value: 0.9499999999999998 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9499999999999998.
# [I 2024-04-08 15:37:13,996] Trial 1 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 1 with value: 0.9583333333333334.
# [I 2024-04-08 15:37:14,022] Trial 2 finished with value: 0.875 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 1 with value: 0.9583333333333334.
# [I 2024-04-08 15:37:14,035] Trial 3 finished with value: 0.7833333333333333 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 1}. Best is trial 1 with value: 0.9583333333333334.
# [I 2024-04-08 15:37:14,049] Trial 4 finished with value: 0.9499999999999998 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 1 with value: 0.9583333333333334.
# [I 2024-04-08 15:37:14,064] Trial 5 finished with value: 1.0 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:14,079] Trial 6 finished with value: 0.8916666666666666 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:14,093] Trial 7 finished with value: 1.0 and parameters: {'n_neighbors': 4, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:14,108] Trial 8 finished with value: 0.9583333333333334 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:14,122] Trial 9 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:14,123] A new study created in memory with name: no-name-3f073787-e173-4d95-b1c7-0b6d167dd785
# [I 2024-04-08 15:37:14,295] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:37:14,553] Trial 1 finished with value: 0.9833333333333334 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 0.9833333333333334.
# [I 2024-04-08 15:37:14,629] Trial 2 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 0.9833333333333334.
# [I 2024-04-08 15:37:14,913] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 0.9833333333333334.
# [I 2024-04-08 15:37:15,238] Trial 4 finished with value: 0.9833333333333334 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 0.9833333333333334.
# [I 2024-04-08 15:37:15,353] Trial 5 finished with value: 0.9833333333333334 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 0.9833333333333334.
# [I 2024-04-08 15:37:15,551] Trial 6 finished with value: 0.9666666666666667 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 0.9833333333333334.
# [I 2024-04-08 15:37:15,644] Trial 7 finished with value: 0.9833333333333334 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 0.9833333333333334.
# [I 2024-04-08 15:37:15,872] Trial 8 finished with value: 0.9833333333333334 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 0.9833333333333334.
# ...
# [I 2024-04-08 15:37:36,873] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:37,108] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:37,211] Trial 7 finished with value: 0.5 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:37,407] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:37,626] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:37,628] A new study created in memory with name: no-name-39530086-3e81-4bf6-9fc0-26e8f723680a
# [I 2024-04-08 15:37:37,641] Trial 0 finished with value: 0.9365079365079367 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,656] Trial 1 finished with value: 0.9166666666666666 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,670] Trial 2 finished with value: 0.9007936507936508 and parameters: {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,708] Trial 3 finished with value: 0.8492063492063493 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,723] Trial 4 finished with value: 0.9007936507936508 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,737] Trial 5 finished with value: 0.9365079365079364 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,755] Trial 6 finished with value: 0.9365079365079367 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,769] Trial 7 finished with value: 0.9365079365079364 and parameters: {'n_neighbors': 5, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,784] Trial 8 finished with value: 0.9206349206349206 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,798] Trial 9 finished with value: 0.9087301587301587 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 0.9365079365079367.
# [I 2024-04-08 15:37:37,799] A new study created in memory with name: no-name-3d119d24-4d30-4597-9fd1-b3fd55d4b7e1
# [I 2024-04-08 15:37:37,979] Trial 0 finished with value: 0.9047619047619048 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.9047619047619048.
# [I 2024-04-08 15:37:38,241] Trial 1 finished with value: 0.8809523809523809 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 0 with value: 0.9047619047619048.
# [I 2024-04-08 15:37:38,317] Trial 2 finished with value: 0.9285714285714285 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:38,606] Trial 3 finished with value: 0.873015873015873 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:38,958] Trial 4 finished with value: 0.888888888888889 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:39,084] Trial 5 finished with value: 0.9206349206349206 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:39,279] Trial 6 finished with value: 0.9206349206349206 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:39,381] Trial 7 finished with value: 0.9047619047619048 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:39,582] Trial 8 finished with value: 0.8809523809523809 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:39,811] Trial 9 finished with value: 0.888888888888889 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 2 with value: 0.9285714285714285.
# [I 2024-04-08 15:37:39,813] A new study created in memory with name: no-name-69b8abbf-43e6-4fe3-975b-708c3db382a4
# [I 2024-04-08 15:37:39,828] Trial 0 finished with value: 0.9444444444444445 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9444444444444445.
# [I 2024-04-08 15:37:39,843] Trial 1 finished with value: 0.9166666666666666 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9444444444444445.
# [I 2024-04-08 15:37:39,857] Trial 2 finished with value: 0.9444444444444445 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9444444444444445.
# [I 2024-04-08 15:37:39,871] Trial 3 finished with value: 0.8611111111111112 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9444444444444445.
# [I 2024-04-08 15:37:39,886] Trial 4 finished with value: 0.9166666666666666 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9444444444444445.
# [I 2024-04-08 15:37:39,899] Trial 5 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:39,914] Trial 6 finished with value: 0.9444444444444445 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:39,928] Trial 7 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:39,943] Trial 8 finished with value: 0.9166666666666666 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:39,956] Trial 9 finished with value: 0.9166666666666666 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 5 with value: 1.0.
# [I 2024-04-08 15:37:39,956] A new study created in memory with name: no-name-692a0f27-da19-49a3-b252-b519ca0099b4
# [I 2024-04-08 15:37:40,129] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:37:40,378] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:40,456] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:40,740] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:41,074] Trial 4 finished with value: 0.9444444444444445 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:41,187] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:41,376] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:41,476] Trial 7 finished with value: 0.9444444444444445 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:41,679] Trial 8 finished with value: 0.9444444444444445 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:41,907] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:41,908] A new study created in memory with name: no-name-137a870b-73cc-499f-b315-0920299f1525
# [I 2024-04-08 15:37:41,922] Trial 0 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:41,937] Trial 1 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:41,950] Trial 2 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:41,962] Trial 3 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:41,976] Trial 4 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:41,990] Trial 5 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:42,002] Trial 6 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:42,015] Trial 7 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:42,029] Trial 8 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:42,045] Trial 9 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:42,047] A new study created in memory with name: no-name-fb82c778-bd0c-473d-86a0-adbb6ed1ed56
# [I 2024-04-08 15:37:42,516] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:37:42,770] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:42,855] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:43,152] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:43,484] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:43,599] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:43,797] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:43,902] Trial 7 finished with value: 0.5 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:44,122] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:44,349] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:44,352] A new study created in memory with name: no-name-a5f36f84-3467-4f28-8fcc-2dc7a5cd359c
# [I 2024-04-08 15:37:44,366] Trial 0 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,391] Trial 1 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,406] Trial 2 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,420] Trial 3 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,435] Trial 4 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,450] Trial 5 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,463] Trial 6 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,478] Trial 7 finished with value: 1.0 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,490] Trial 8 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,504] Trial 9 finished with value: 1.0 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 1.0.
# [I 2024-04-08 15:37:44,505] A new study created in memory with name: no-name-c5bf2953-81d4-4e26-91a8-0c9bfcf0b848
# [I 2024-04-08 15:37:44,677] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}. Best is trial 0 with value: 0.5.
# [I 2024-04-08 15:37:44,936] Trial 1 finished with value: 1.0 and parameters: {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:45,011] Trial 2 finished with value: 0.5 and parameters: {'n_estimators': 152, 'max_depth': 71, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:45,312] Trial 3 finished with value: 0.5 and parameters: {'n_estimators': 737, 'max_depth': 2, 'min_samples_split': 12}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:45,646] Trial 4 finished with value: 1.0 and parameters: {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:45,758] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 265, 'max_depth': 6, 'min_samples_split': 7}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:45,988] Trial 6 finished with value: 0.5 and parameters: {'n_estimators': 489, 'max_depth': 5, 'min_samples_split': 8}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:46,087] Trial 7 finished with value: 0.5 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:46,293] Trial 8 finished with value: 1.0 and parameters: {'n_estimators': 510, 'max_depth': 49, 'min_samples_split': 4}. Best is trial 1 with value: 1.0.
# [I 2024-04-08 15:37:46,516] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}. Best is trial 1 with value: 1.0.

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %% [markdown]
# ## _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-

# %%
default_models
# Out:
# __main__.default_models

# %% [markdown]
# ## ALL THE DICTS TO COMPILE

# %% [markdown]
# ### CLASS feature_selection

# %%
# dicts
fclass.selected_feature_dict
fclass.sample_dict
fclass.target_key_dict

# lists
fclass.ordered_hierarchy_keys
fclass.feature_keys

# ints 
fclass.n_levels # how many level in the hierarchy-- int 
fclass.select_top_n_features # int user sets to select top features -- int

info(fclass)
# Out:
# type is <class '__main__.feature_selection'> will try printing using "get_class_info2"
# feature_keys                type->   list    length->   3698  ...cg25947555', 'cg26730347', 'cg27454842']
# make_feature_selection_dict type->   method  None  ->   None  ...eature_selection object at 0x2b1f25520>>
# n_levels                    type->   int     None  ->   None  > 3
# ordered_hierarchy_keys      type->   list    length->   3     ..._code', 'Family_code', 'Class_v12_code']
# sample_dict                 type->   dict    length->   26    ...: Family_code, Length: 273, dtype: bool}
# select_top_n_features       type->   int     None  ->   None  > 10
# selected_feature_dict       type->   dict    length->   26    ...', 'cg01273336'],
#       dtype='object')}
# target_key_dict             type->   dict    length->   26    ...de', 'UNCERT_DIFF'): ['Class_v12_code']}

# %%
info_dict.vis(fclass.selected_feature_dict['Full_model'])
# Out:
#  type: Index, len: 10

# %% [markdown]
# ### CLASS RandomForestFeatureSelection

# %%
RFFS.RF_feature_importance_dict # for each feature passed in, number reprenting feature importance
RFFS.RF_feature_selection_model_dict # one model per each global key (model for particular superfamily family class etc) use 
# to select features, might toss this for final save. 
RFFS.RF_selected_features # index to selected features to the dataframe inputed 



# these are direct copies from the previous class
RFFS.selected_feature_dict
RFFS.sample_dict
RFFS.ordered_hierarchy_keys
RFFS.target_key_dict



info(RFFS)
# Out:
# type is <class '__main__.RandomForestFeatureSelection'> will try printing using "get_class_info2"
# RF_feature_importance_dict      type->   dict                        length->   26    ...9, 0.15400411, 0.07145791, 0.07022587])}
# RF_feature_selection_model_dict type->   dict                        length->   26    ...fier(n_estimators=500, random_state=42)}
# RF_selected_features            type->   dict                        length->   26    ...g11165254', 'cg09814029', 'cg03094555']}
# feature_selection_class         type->   __main__.feature_selection  None  ->   None  ...feature_selection object at 0x2b1f25520>
# ordered_hierarchy_keys          type->   list                        length->   3     ..._code', 'Family_code', 'Class_v12_code']
# run_RF_feature_selection        type->   method                      None  ->   None  ...FeatureSelection object at 0x2b1f374d0>>
# sample_dict                     type->   dict                        length->   26    ...: Family_code, Length: 273, dtype: bool}
# select_top_n_features           type->   int                         None  ->   None  > 3
# selected_feature_dict           type->   dict                        length->   26    ...', 'cg01273336'],
#       dtype='object')}
# target_key_dict                 type->   dict                        length->   26    ...de', 'UNCERT_DIFF'): ['Class_v12_code']}

# %%
info_dict.vis(RFFS.RF_selected_features)
# Out:
# ├── Full_model                                  : type: list, len: 3 ['cg10623600', 'cg08684879', 'cg01207684']
# ├── ('Superfamily_code', 'CNTRL')               : type: list, len: 3 ['cg03683087', 'cg10623600', 'cg05876564']
# ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: list, len: 3 ['cg24665113', 'cg16078210', 'cg16175703']
# ├── ('Superfamily_code', 'EMBRY')               : type: list, len: 3 ['cg14710529', 'cg16410524', 'cg03909863']
# ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: list, len: 3 ['cg09884146', 'cg07060794', 'cg03350900']
# ├── ('Superfamily_code', 'HEMA')                : type: list, len: 3 ['cg02081701', 'cg10124651', 'cg04737131']
# ├── ('Superfamily_code', 'MELANO')              : type: list, len: 3 ['cg03110368', 'cg02675308', 'cg25506747']
# ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: list, len: 3 ['cg17645677', 'cg01207684', 'cg13628022']
# ├── ('Superfamily_code', 'PIN_RET')             : type: list, len: 3 ['cg15188398', 'cg21185289', 'cg15157241']
# ├── ('Superfamily_code', 'SELLAR')              : type: list, len: 3 ['cg06132069', 'cg24862202', 'cg15337521']
# ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: list, len: 3 ['cg17090968', 'cg11235391', 'cg04209913']
# ├── ('Family_code', 'CNTL_BRAIN')               : type: list, len: 3 ['cg05876564', 'cg22630748', 'cg12819548']
# ├── ('Family_code', 'CRANIO')                   : type: list, len: 3 ['cg24164564', 'cg16759416', 'cg13754720']
# ├── ('Family_code', 'CTRL_TME')                 : type: list, len: 3 ['cg04209913', 'cg14365143', 'cg10193711']
# ├── ('Family_code', 'EPENDYM')                  : type: list, len: 3 ['cg02928365', 'cg09056876', 'cg12284769']
# ├── ('Family_code', 'ESTHESIO')                 : type: list, len: 3 ['cg07307388', 'cg25957967', 'cg07586489']
# ├── ('Family_code', 'GLIONEUR_NEUR')            : type: list, len: 3 ['cg14064526', 'cg09056876', 'cg27508055']
# ├── ('Family_code', 'HGG')                      : type: list, len: 3 ['cg20302533', 'cg14279121', 'cg06480736']
# ├── ('Family_code', 'MB')                       : type: list, len: 3 ['cg04209913', 'cg15837233', 'cg25479916']
# ├── ('Family_code', 'OTHER_EMBRY')              : type: list, len: 3 ['cg11242791', 'cg17904575', 'cg00699569']
# ├── ('Family_code', 'PAP_PINEAL')               : type: list, len: 3 ['cg21376454', 'cg16406892', 'cg16449012']
# ├── ('Family_code', 'PINEOBLAST')               : type: list, len: 3 ['cg25778892', 'cg18947175', 'cg12173150']
# ├── ('Family_code', 'PIT_AD')                   : type: list, len: 3 ['cg03625415', 'cg26380106', 'cg11412046']
# ├── ('Family_code', 'PLEXUS')                   : type: list, len: 3 ['cg11095319', 'cg25093234', 'cg10623600']
# ├── ('Family_code', 'SFT')                      : type: list, len: 3 ['cg08684879', 'cg24106661', 'cg03669394']
# └── ('Family_code', 'UNCERT_DIFF')              : type: list, len: 3 ['cg11165254', 'cg09814029', 'cg03094555']

# %%
info_dict.vis(RFFS.RF_feature_selection_model_dict)
# Out:
# ├── Full_model                                  : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'CNTRL')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'EMBRY')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'HEMA')                : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'MELANO')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'PIN_RET')             : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Superfamily_code', 'SELLAR')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'CNTL_BRAIN')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'CRANIO')                   : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'CTRL_TME')                 : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'EPENDYM')                  : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'ESTHESIO')                 : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'GLIONEUR_NEUR')            : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'HGG')                      : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'MB')                       : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'OTHER_EMBRY')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'PAP_PINEAL')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'PINEOBLAST')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'PIT_AD')                   : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'PLEXUS')                   : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── ('Family_code', 'SFT')                      : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# └── ('Family_code', 'UNCERT_DIFF')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)

# %% [markdown]
# ### CLASS TrainingData

# %%
# training_data_class is only organizing data and nothing new is created 
# if later we need to see the exact training data used for these models we will call this 
# class again and generate it this way. the class fclass and RFFS contain all the infomration 
# needed to index df to recreate this. DF will and should be stored seperately. since copied of 
# this file will increase storage a lot. 


info(training_data_class)
# Out:
# type is <class '__main__.TrainingData'> will try printing using "get_class_info2"
# get_training_data     type->   method  None  ->   None  ...n__.TrainingData object at 0x2b1f24fb0>>
# sample_dict           type->   dict    length->   26    ...: Family_code, Length: 273, dtype: bool}
# selected_feature_dict type->   dict    length->   26    ...g11165254', 'cg09814029', 'cg03094555']}
# target_dict           type->   dict    length->   26    ...de', 'UNCERT_DIFF'): ['Class_v12_code']}

# %% [markdown]
# ### CLASS TrainAllModels

# %%
# for the Train all models class we use optuna so a new set of dicitonaries are created

# is the training_data_class class from above passed in so we can ignore that

# dict 
TAM.best_optuna_model_info # used to make life easier. reorganizes important data from TAM.optuna so that we dont have to dig in this. 
# contains the following where it refers only to the best model. this is waht is used to select the paramters to actually train on. 
"""
info_dict.vis(TAM.best_optuna_model_info['Full_model'])


├── model_key            : type: str, len: N/A RF
├── params               : type: dict, len: 3 {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}
│   ├── n_estimators     : type: int, len: N/A 850
│   ├── max_depth        : type: int, len: N/A 4
│   └── min_samples_split: type: int, len: N/A 4
├── metric_performance   : type: float, len: N/A 0.8796031427326194
├── is_multi_class       : type: bool, len: N/A True
├── n_trials             : type: int, len: N/A 10
├── cv_folds             : type: int, len: N/A 3
├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
└── direction_to_optimize: type: str, len: N/A maximize


"""
TAM.optuna # has the following structure
# L1-- heiarchy keys for each model (i.e. global_keys) 
# L2-- ---- each of the model types being compared (in this case KNN and RF but this can be expanded on at the DefaultOptunaStudies class 
# L3-- ---- ----for each model it has these keys: study, best_params, best_value, IS_BEST_MODEL. best value is best metric score of best 
# ---- ---- ----optuna model, best_params is best params of htis model and IS_BEST_MODEL is True for only one model type at L2. study is 
# ---- ---- ----the full optuna study. with added data at X['study'].metadata that look like this 
"""
TAM.optuna[('Family_code', 'PLEXUS')]['KNN']['study'].metadata


{'metric_to_optimize': 'roc_auc_ovr',
 'direction_to_optimize': 'maximize',
 'n_trials': 10,
 'cv_folds': 3,
 'is_multi_class': True,
 'binary_and_multi_class_metrics_list': ['roc_auc', 'roc_auc_ovr']}

"""


info(TAM)
# Out:
# type is <class '__main__.TrainAllModels'> will try printing using "get_class_info2"
# TD                           type->   __main__.TrainingData  None  ->   None  ...in__.TrainingData object at 0x2b1f24fb0>
# best_optuna_model_info       type->   dict                   length->   26    ...', 'direction_to_optimize': 'maximize'}}
# model_hyper_parameter_tuning type->   method                 None  ->   None  ..._.TrainAllModels object at 0x2b1f34080>>
# optuna                       type->   dict                   length->   26    ...t_value': 1.0, 'IS_BEST_MODEL': False}}}
# train_all_models             type->   method                 None  ->   None  ..._.TrainAllModels object at 0x2b1f34080>>

# %%
info(TAM.optuna)
# Out:
# type is dict
# Full_model                                   type->   dict   len-> 2  ...796031427326194, 'IS_BEST_MODEL': True}}
# ('Family_code', 'PLEXUS')                    type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'PIT_AD')                    type->   dict   len-> 2  ...85714285714285, 'IS_BEST_MODEL': False}}
# ('Family_code', 'PINEOBLAST')                type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'PAP_PINEAL')                type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'OTHER_EMBRY')               type->   dict   len-> 2  ...66666666666667, 'IS_BEST_MODEL': False}}
# ('Family_code', 'MB')                        type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'HGG')                       type->   dict   len-> 2  ...737373737373737, 'IS_BEST_MODEL': True}}
# ('Family_code', 'GLIONEUR_NEUR')             type->   dict   len-> 2  ...41269841269842, 'IS_BEST_MODEL': False}}
# ('Family_code', 'ESTHESIO')                  type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'EPENDYM')                   type->   dict   len-> 2  ...14814814814815, 'IS_BEST_MODEL': False}}
# ('Family_code', 'CTRL_TME')                  type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'CRANIO')                    type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'CNTL_BRAIN')                type->   dict   len-> 2  ...33333333333334, 'IS_BEST_MODEL': False}}
# ('Family_code', 'CIRC_ASTR_GLIO')            type->   dict   len-> 2  ...66666666666666, 'IS_BEST_MODEL': False}}
# ('Superfamily_code', 'SELLAR')               type->   dict   len-> 2  ....98070987654321, 'IS_BEST_MODEL': True}}
# ('Superfamily_code', 'PIN_RET')              type->   dict   len-> 2  ...58333333333333, 'IS_BEST_MODEL': False}}
# ('Superfamily_code', 'MESEN_NONMENING')      type->   dict   len-> 2  ...66666666666666, 'IS_BEST_MODEL': False}}
# ('Superfamily_code', 'MELANO')               type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Superfamily_code', 'HEMA')                 type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR') type->   dict   len-> 2  ...547162926473272, 'IS_BEST_MODEL': True}}
# ('Superfamily_code', 'EMBRY')                type->   dict   len-> 2  ...88888888888889, 'IS_BEST_MODEL': False}}
# ('Superfamily_code', 'CRAN_PARASPIN')        type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Superfamily_code', 'CNTRL')                type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'SFT')                       type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}
# ('Family_code', 'UNCERT_DIFF')               type->   dict   len-> 2  ...st_value': 1.0, 'IS_BEST_MODEL': False}}

# %%
info_dict.vis(TAM.optuna[('Family_code', 'PLEXUS')])
# Out:
# ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b36a32f0>, 'best_params': {'n_neighbors': 3, 'weigh...
# │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b36a32f0>
# │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 3, 'weights': 'distance', 'p': 1}
# │   │   ├── n_neighbors: type: int, len: N/A 3
# │   │   ├── weights    : type: str, len: N/A distance
# │   │   └── p          : type: int, len: N/A 1
# │   ├── best_value   : type: float, len: N/A 1.0
# │   └── IS_BEST_MODEL: type: bool, len: N/A True
# └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x174a1db20>, 'best_params': {'n_estimators': 639, 'ma...
#     ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x174a1db20>
#     ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
#     │   ├── n_estimators     : type: int, len: N/A 639
#     │   ├── max_depth        : type: int, len: N/A 3
#     │   └── min_samples_split: type: int, len: N/A 3
#     ├── best_value   : type: float, len: N/A 1.0
#     └── IS_BEST_MODEL: type: bool, len: N/A False

# %%
info_dict.vis(TAM.optuna[('Family_code', 'PLEXUS')]['KNN'])
# Out:
# ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b36a32f0>
# ├── best_params  : type: dict, len: 3 {'n_neighbors': 3, 'weights': 'distance', 'p': 1}
# │   ├── n_neighbors: type: int, len: N/A 3
# │   ├── weights    : type: str, len: N/A distance
# │   └── p          : type: int, len: N/A 1
# ├── best_value   : type: float, len: N/A 1.0
# └── IS_BEST_MODEL: type: bool, len: N/A True

# %%
TAM.optuna[('Family_code', 'PLEXUS')]['KNN']['study'].metadata
# Out:
# {'metric_to_optimize': 'roc_auc_ovr',
#  'direction_to_optimize': 'maximize',
#  'n_trials': 10,
#  'cv_folds': 3,
#  'is_multi_class': True,
#  'binary_and_multi_class_metrics_list': ['roc_auc', 'roc_auc_ovr']}

# %%
info_dict.vis(TAM.best_optuna_model_info['Full_model'])
# Out:
# ├── model_key            : type: str, len: N/A RF
# ├── params               : type: dict, len: 3 {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}
# │   ├── n_estimators     : type: int, len: N/A 850
# │   ├── max_depth        : type: int, len: N/A 4
# │   └── min_samples_split: type: int, len: N/A 4
# ├── metric_performance   : type: float, len: N/A 0.8796031427326194
# ├── is_multi_class       : type: bool, len: N/A True
# ├── n_trials             : type: int, len: N/A 10
# ├── cv_folds             : type: int, len: N/A 3
# ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
# └── direction_to_optimize: type: str, len: N/A maximize

# %% [markdown]
# ### CLASS ,.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.'

# %% [markdown]
# ### CLASS ,.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.',.'

# %% [markdown]
# # save all the data into a single dictionary and file.

# %%
# Initialize the mega_dict
mega_dict = {}

# Adding dicts from fclass
mega_dict['IQR_selected_feature_dict'] = fclass.selected_feature_dict
mega_dict['sample_dict'] = fclass.sample_dict
mega_dict['target_key_dict'] = fclass.target_key_dict

# Adding lists from fclass
mega_dict['ordered_hierarchy_keys'] = fclass.ordered_hierarchy_keys
mega_dict['feature_keys'] = fclass.feature_keys

# Adding ints from fclass
mega_dict['n_hierarchy_levels'] = fclass.n_levels
mega_dict['IQR_select_top_n_features'] = fclass.select_top_n_features

# Adding attributes from RFFS
mega_dict['RF_feature_importance_dict'] = RFFS.RF_feature_importance_dict
mega_dict['RF_feature_selection_model_dict'] = RFFS.RF_feature_selection_model_dict
mega_dict['RF_selected_feature_dict'] = RFFS.RF_selected_features

# Adding attributes from TAM
mega_dict['optuna'] = TAM.optuna
mega_dict['best_optuna_model_info'] = TAM.best_optuna_model_info

# The mega_dict now contains all the selected keys and their values from the different classes.

# %%
info(mega_dict)
# Out:
# type is dict
# IQR_selected_feature_dict       type->   dict   len-> 26  ...', 'cg01273336'],
#       dtype='object')}
# sample_dict                     type->   dict   len-> 26  ...: Family_code, Length: 273, dtype: bool}
# target_key_dict                 type->   dict   len-> 26  ...de', 'UNCERT_DIFF'): ['Class_v12_code']}
# RF_feature_importance_dict      type->   dict   len-> 26  ...9, 0.15400411, 0.07145791, 0.07022587])}
# RF_feature_selection_model_dict type->   dict   len-> 26  ...fier(n_estimators=500, random_state=42)}
# RF_selected_features            type->   dict   len-> 26  ...g11165254', 'cg09814029', 'cg03094555']}
# optuna                          type->   dict   len-> 26  ...t_value': 1.0, 'IS_BEST_MODEL': False}}}
# best_optuna_model_info          type->   dict   len-> 26  ...', 'direction_to_optimize': 'maximize'}}
# n_hierarchy_levels              type->   int    None->None  > 3
# IQR_select_top_n_features       type->   int    None->None  > 10
# ordered_hierarchy_keys          type->   list   len-> 3  ..._code', 'Family_code', 'Class_v12_code']
# feature_keys                    type->   list   len-> 3698  ...cg25947555', 'cg26730347', 'cg27454842']

# %%
for k in mega_dict:

    info_dict.vis(mega_dict, [[k]])
    print('-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_')
# Out:
# └── IQR_selected_feature_dict: type: dict, len: 26 {'Full_model': Index(['cg04209913', 'cg24981593', 'cg10623600', 'cg01207684', 'cg25286482',
#        '...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── sample_dict: type: dict, len: 26 {'Full_model': 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 268    True
# 2...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── target_key_dict: type: dict, len: 26 {'Full_model': ['Superfamily_code'], ('Superfamily_code', 'CNTRL'): ['Family_code'], ('Superfamily_c...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── ordered_hierarchy_keys: type: list, len: 3 ['Superfamily_code', 'Family_code', 'Class_v12_code']
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── feature_keys: type: list, len: 3698 ['cg00212031', 'cg00650640', 'cg02010442', 'cg03272642', 'cg04413754', 'cg05467600', 'cg06443675', '...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── n_hierarchy_levels: type: int, len: N/A 3
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── IQR_select_top_n_features: type: int, len: N/A 10
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── RF_feature_importance_dict: type: dict, len: 26 {'Full_model': array([0.06282596, 0.09287444, 0.15709464, 0.11467024, 0.09381881,
#        0.08881982,...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── RF_feature_selection_model_dict: type: dict, len: 26 {'Full_model': RandomForestClassifier(n_estimators=500, random_state=42), ('Superfamily_code', 'CNTR...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── RF_selected_features: type: dict, len: 26 {'Full_model': ['cg10623600', 'cg08684879', 'cg01207684'], ('Superfamily_code', 'CNTRL'): ['cg036830...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── optuna: type: dict, len: 26 {'Full_model': {'KNN': {'study': <optuna.study.study.Study object at 0x2b35c8200>, 'best_params': {'...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# └── best_optuna_model_info: type: dict, len: 26 {'Full_model': {'model_key': 'RF', 'params': {'n_estimators': 850, 'max_depth': 4, 'min_samples_spli...
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %%
info_dict.vis(mega_dict)
# Out:
# ├── IQR_selected_feature_dict      : type: dict, len: 26 {'Full_model': Index(['cg04209913', 'cg24981593', 'cg10623600', 'cg01207684', 'cg25286482',
#        '...
# │   ├── Full_model                                  : type: Index, len: 10 Index(['cg04209913', 'cg24981593', 'cg10623600', 'cg01207684', 'cg25286482',
#        'cg06132069', 'c...
# │   ├── ('Superfamily_code', 'CNTRL')               : type: Index, len: 10 Index(['cg10193711', 'cg11854392', 'cg03683087', 'cg05876564', 'cg04209913',
#        'cg26348348', 'c...
# │   ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: Index, len: 10 Index(['cg22972519', 'cg27436952', 'cg21376454', 'cg16175703', 'cg24665113',
#        'cg26703880', 'c...
# │   ├── ('Superfamily_code', 'EMBRY')               : type: Index, len: 10 Index(['cg11740348', 'cg24164564', 'cg03909863', 'cg25957967', 'cg16410524',
#        'cg04209913', 'c...
# │   ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: Index, len: 10 Index(['cg17090968', 'cg04209913', 'cg09799983', 'cg03350900', 'cg11740348',
#        'cg07060794', 'c...
# │   ├── ('Superfamily_code', 'HEMA')                : type: Index, len: 10 Index(['cg26348348', 'cg24344662', 'cg02081701', 'cg20992181', 'cg04737131',
#        'cg06609197', 'c...
# │   ├── ('Superfamily_code', 'MELANO')              : type: Index, len: 10 Index(['cg09799983', 'cg25916282', 'cg15532640', 'cg03078363', 'cg25506747',
#        'cg21932416', 'c...
# │   ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: Index, len: 10 Index(['cg26299044', 'cg10623600', 'cg12694372', 'cg05658107', 'cg01207684',
#        'cg17645677', 'c...
# │   ├── ('Superfamily_code', 'PIN_RET')             : type: Index, len: 10 Index(['cg21185289', 'cg15188398', 'cg09053081', 'cg04209913', 'cg15157241',
#        'cg24164564', 'c...
# │   ├── ('Superfamily_code', 'SELLAR')              : type: Index, len: 10 Index(['cg06132069', 'cg25406442', 'cg15337521', 'cg09388540', 'cg12511749',
#        'cg12733396', 'c...
# │   ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: Index, len: 10 Index(['cg17090968', 'cg12676702', 'cg21932416', 'cg04209913', 'cg10950297',
#        'cg05916707', 'c...
# │   ├── ('Family_code', 'CNTL_BRAIN')               : type: Index, len: 10 Index(['cg27622679', 'cg12819548', 'cg21550442', 'cg08785724', 'cg22630748',
#        'cg05393025', 'c...
# │   ├── ('Family_code', 'CRANIO')                   : type: Index, len: 10 Index(['cg10193711', 'cg16759416', 'cg24164564', 'cg19889066', 'cg16206341',
#        'cg14321539', 'c...
# │   ├── ('Family_code', 'CTRL_TME')                 : type: Index, len: 10 Index(['cg10623600', 'cg22193385', 'cg04209913', 'cg00698771', 'cg10193711',
#        'cg03683087', 'c...
# │   ├── ('Family_code', 'EPENDYM')                  : type: Index, len: 10 Index(['cg26348348', 'cg12434898', 'cg02928365', 'cg12456011', 'cg24412662',
#        'cg03386869', 'c...
# │   ├── ('Family_code', 'ESTHESIO')                 : type: Index, len: 10 Index(['cg25957967', 'cg23484159', 'cg26730347', 'cg07586489', 'cg15633056',
#        'cg07307388', 'c...
# │   ├── ('Family_code', 'GLIONEUR_NEUR')            : type: Index, len: 10 Index(['cg03386869', 'cg16759416', 'cg15337521', 'cg27508055', 'cg17227257',
#        'cg11289677', 'c...
# │   ├── ('Family_code', 'HGG')                      : type: Index, len: 10 Index(['cg24164564', 'cg09053081', 'cg09799983', 'cg06480736', 'cg00591844',
#        'cg14279121', 'c...
# │   ├── ('Family_code', 'MB')                       : type: Index, len: 10 Index(['cg04209913', 'cg24164564', 'cg25957967', 'cg15837233', 'cg23598080',
#        'cg09799983', 'c...
# │   ├── ('Family_code', 'OTHER_EMBRY')              : type: Index, len: 10 Index(['cg01207684', 'cg17904575', 'cg17090968', 'cg23638042', 'cg18409732',
#        'cg24164564', 'c...
# │   ├── ('Family_code', 'PAP_PINEAL')               : type: Index, len: 10 Index(['cg20895877', 'cg04209913', 'cg16449012', 'cg09799983', 'cg16406892',
#        'cg14473743', 'c...
# │   ├── ('Family_code', 'PINEOBLAST')               : type: Index, len: 10 Index(['cg00698771', 'cg18947175', 'cg25778892', 'cg12173150', 'cg01510696',
#        'cg23933095', 'c...
# │   ├── ('Family_code', 'PIT_AD')                   : type: Index, len: 10 Index(['cg22807732', 'cg03625415', 'cg25406442', 'cg13002222', 'cg09388540',
#        'cg26380106', 'c...
# │   ├── ('Family_code', 'PLEXUS')                   : type: Index, len: 10 Index(['cg07795402', 'cg10623600', 'cg00650640', 'cg21185289', 'cg24996154',
#        'cg09053081', 'c...
# │   ├── ('Family_code', 'SFT')                      : type: Index, len: 10 Index(['cg09798202', 'cg22974630', 'cg08684879', 'cg03669394', 'cg24106661',
#        'cg09884146', 'c...
# │   └── ('Family_code', 'UNCERT_DIFF')              : type: Index, len: 10 Index(['cg00698771', 'cg09814029', 'cg00590173', 'cg03078363', 'cg11165254',
#        'cg17090968', 'c...
# ├── sample_dict                    : type: dict, len: 26 {'Full_model': 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 268    True
# 2...
# │   ├── Full_model                                  : type: Series, len: 273 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 268    True
# 269    True
# 270 ...
# │   ├── ('Superfamily_code', 'CNTRL')               : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268     True
# 269     T...
# │   ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Superfamily_code', 'EMBRY')               : type: Series, len: 273 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Superfamily_code', 'HEMA')                : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Superfamily_code', 'MELANO')              : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Superfamily_code', 'PIN_RET')             : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Superfamily_code', 'SELLAR')              : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'CNTL_BRAIN')               : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268     True
# 269     T...
# │   ├── ('Family_code', 'CRANIO')                   : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'CTRL_TME')                 : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'EPENDYM')                  : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'ESTHESIO')                 : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'GLIONEUR_NEUR')            : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'HGG')                      : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'MB')                       : type: Series, len: 273 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'OTHER_EMBRY')              : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'PAP_PINEAL')               : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'PINEOBLAST')               : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'PIT_AD')                   : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'PLEXUS')                   : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   ├── ('Family_code', 'SFT')                      : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# │   └── ('Family_code', 'UNCERT_DIFF')              : type: Series, len: 273 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 268    False
# 269    Fa...
# ├── target_key_dict                : type: dict, len: 26 {'Full_model': ['Superfamily_code'], ('Superfamily_code', 'CNTRL'): ['Family_code'], ('Superfamily_c...
# │   ├── Full_model                                  : type: list, len: 1 ['Superfamily_code']
# │   ├── ('Superfamily_code', 'CNTRL')               : type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'EMBRY')               : type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'HEMA')                : type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'MELANO')              : type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'PIN_RET')             : type: list, len: 1 ['Family_code']
# │   ├── ('Superfamily_code', 'SELLAR')              : type: list, len: 1 ['Family_code']
# │   ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'CNTL_BRAIN')               : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'CRANIO')                   : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'CTRL_TME')                 : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'EPENDYM')                  : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'ESTHESIO')                 : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'GLIONEUR_NEUR')            : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'HGG')                      : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'MB')                       : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'OTHER_EMBRY')              : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'PAP_PINEAL')               : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'PINEOBLAST')               : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'PIT_AD')                   : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'PLEXUS')                   : type: list, len: 1 ['Class_v12_code']
# │   ├── ('Family_code', 'SFT')                      : type: list, len: 1 ['Class_v12_code']
# │   └── ('Family_code', 'UNCERT_DIFF')              : type: list, len: 1 ['Class_v12_code']
# ├── ordered_hierarchy_keys         : type: list, len: 3 ['Superfamily_code', 'Family_code', 'Class_v12_code']
# ├── feature_keys                   : type: list, len: 3698 ['cg00212031', 'cg00650640', 'cg02010442', 'cg03272642', 'cg04413754', 'cg05467600', 'cg06443675', '...
# ├── n_hierarchy_levels             : type: int, len: N/A 3
# ├── IQR_select_top_n_features      : type: int, len: N/A 10
# ├── RF_feature_importance_dict     : type: dict, len: 26 {'Full_model': array([0.06282596, 0.09287444, 0.15709464, 0.11467024, 0.09381881,
#        0.08881982,...
# │   ├── Full_model                                  : type: ndarray, shape: shape: (10,) [0.06282596 0.09287444 0.15709464 0.11467024 0.09381881 0.08881982
#  0.09645339 0.08934002 0.11805322...
# │   ├── ('Superfamily_code', 'CNTRL')               : type: ndarray, shape: shape: (10,) [0.08465862 0.08479279 0.23567554 0.10637024 0.05013408 0.10320018
#  0.10574789 0.11187056 0.04821244...
# │   ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: ndarray, shape: shape: (10,) [0.08427779 0.07810413 0.0971057  0.0993528  0.18398796 0.07735185
#  0.09285402 0.10003234 0.09223705...
# │   ├── ('Superfamily_code', 'EMBRY')               : type: ndarray, shape: shape: (10,) [0.10849345 0.02176023 0.12310607 0.04127762 0.14484185 0.02741892
#  0.36541019 0.10030167 0.03238861...
# │   ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: ndarray, shape: shape: (10,) [0.06163896 0.10664522 0.07312212 0.13138876 0.08842105 0.13587196
#  0.06559539 0.12230443 0.14084371...
# │   ├── ('Superfamily_code', 'HEMA')                : type: ndarray, shape: shape: (10,) [0.09445585 0.10882957 0.11498973 0.1026694  0.10882957 0.09856263
#  0.09650924 0.06776181 0.09856263...
# │   ├── ('Superfamily_code', 'MELANO')              : type: ndarray, shape: shape: (10,) [0.15838509 0.05931677 0.05300207 0.04689441 0.16480331 0.05113872
#  0.05383023 0.02795031 0.20331263...
# │   ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: ndarray, shape: shape: (10,) [0.06254307 0.03023353 0.06237851 0.12031331 0.15887527 0.16823383
#  0.05731439 0.05653202 0.13660387...
# │   ├── ('Superfamily_code', 'PIN_RET')             : type: ndarray, shape: shape: (10,) [0.16781517 0.17644528 0.03936298 0.05968204 0.13343475 0.04985241
#  0.13054677 0.07962021 0.09027822...
# │   ├── ('Superfamily_code', 'SELLAR')              : type: ndarray, shape: shape: (10,) [0.24002025 0.0386828  0.13373552 0.08109723 0.04530066 0.05954312
#  0.21379988 0.01843104 0.05104971...
# │   ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: ndarray, shape: shape: (10,) [0.14715747 0.1174074  0.09543521 0.12582329 0.05887455 0.08878635
#  0.09414555 0.06228588 0.14343831...
# │   ├── ('Family_code', 'CNTL_BRAIN')               : type: ndarray, shape: shape: (10,) [0.06657485 0.12688467 0.10621238 0.05983586 0.14658308 0.09067318
#  0.10568472 0.06607167 0.14824574...
# │   ├── ('Family_code', 'CRANIO')                   : type: ndarray, shape: shape: (10,) [0.09465021 0.1090535  0.11522634 0.10288066 0.10493827 0.10288066
#  0.09465021 0.06790123 0.10082305...
# │   ├── ('Family_code', 'CTRL_TME')                 : type: ndarray, shape: shape: (10,) [0.09445585 0.10882957 0.11498973 0.1026694  0.10882957 0.09856263
#  0.09650924 0.06776181 0.09856263...
# │   ├── ('Family_code', 'EPENDYM')                  : type: ndarray, shape: shape: (10,) [0.08107375 0.10313545 0.14484641 0.08209741 0.0947521  0.08060114
#  0.11544715 0.11363572 0.09964483...
# │   ├── ('Family_code', 'ESTHESIO')                 : type: ndarray, shape: shape: (10,) [0.17315574 0.0607582  0.04497951 0.16946721 0.04631148 0.17592213
#  0.08913934 0.1414959  0.05696721...
# │   ├── ('Family_code', 'GLIONEUR_NEUR')            : type: ndarray, shape: shape: (10,) [0.10104731 0.07437011 0.08871656 0.1150845  0.10143334 0.09276295
#  0.12065193 0.08090673 0.11638642...
# │   ├── ('Family_code', 'HGG')                      : type: ndarray, shape: shape: (10,) [0.11252591 0.09310745 0.07910716 0.11406875 0.10974321 0.11485121
#  0.11944634 0.08872191 0.0891902 ...
# │   ├── ('Family_code', 'MB')                       : type: ndarray, shape: shape: (10,) [0.14608849 0.10780679 0.0660909  0.13992886 0.04445135 0.1042737
#  0.08336474 0.09234252 0.11312159 ...
# │   ├── ('Family_code', 'OTHER_EMBRY')              : type: ndarray, shape: shape: (10,) [0.10702201 0.12026306 0.09900746 0.07519619 0.09858004 0.07472218
#  0.11375907 0.15166541 0.08452169...
# │   ├── ('Family_code', 'PAP_PINEAL')               : type: ndarray, shape: shape: (10,) [0.13880903 0.11909651 0.14291581 0.02566735 0.14599589 0.05728953
#  0.04476386 0.03901437 0.13963039...
# │   ├── ('Family_code', 'PINEOBLAST')               : type: ndarray, shape: shape: (10,) [0.09876543 0.11728395 0.12962963 0.11316872 0.1090535  0.11111111
#  0.09876543 0.07201646 0.10493827...
# │   ├── ('Family_code', 'PIT_AD')                   : type: ndarray, shape: shape: (10,) [0.09116498 0.1419373  0.10131705 0.09725431 0.10604468 0.12675239
#  0.07918422 0.07490085 0.07423114...
# │   ├── ('Family_code', 'PLEXUS')                   : type: ndarray, shape: shape: (10,) [0.12656364 0.12749406 0.06428069 0.09097027 0.11246386 0.06612847
#  0.06338101 0.13531298 0.13299342...
# │   ├── ('Family_code', 'SFT')                      : type: ndarray, shape: shape: (10,) [0.12628337 0.13141684 0.14681725 0.1386037  0.14579055 0.04517454
#  0.02669405 0.05749487 0.13552361...
# │   └── ('Family_code', 'UNCERT_DIFF')              : type: ndarray, shape: shape: (10,) [0.04435318 0.19276181 0.09055441 0.0523614  0.20708419 0.07756674
#  0.03963039 0.15400411 0.07145791...
# ├── RF_feature_selection_model_dict: type: dict, len: 26 {'Full_model': RandomForestClassifier(n_estimators=500, random_state=42), ('Superfamily_code', 'CNTR...
# │   ├── Full_model                                  : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'CNTRL')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'EMBRY')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'HEMA')                : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'MELANO')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'PIN_RET')             : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Superfamily_code', 'SELLAR')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'CNTL_BRAIN')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'CRANIO')                   : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'CTRL_TME')                 : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'EPENDYM')                  : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'ESTHESIO')                 : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'GLIONEUR_NEUR')            : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'HGG')                      : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'MB')                       : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'OTHER_EMBRY')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'PAP_PINEAL')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'PINEOBLAST')               : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'PIT_AD')                   : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'PLEXUS')                   : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   ├── ('Family_code', 'SFT')                      : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# │   └── ('Family_code', 'UNCERT_DIFF')              : type: RandomForestClassifier, len: 500 RandomForestClassifier(n_estimators=500, random_state=42)
# ├── RF_selected_features           : type: dict, len: 26 {'Full_model': ['cg10623600', 'cg08684879', 'cg01207684'], ('Superfamily_code', 'CNTRL'): ['cg036830...
# │   ├── Full_model                                  : type: list, len: 3 ['cg10623600', 'cg08684879', 'cg01207684']
# │   ├── ('Superfamily_code', 'CNTRL')               : type: list, len: 3 ['cg03683087', 'cg10623600', 'cg05876564']
# │   ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: list, len: 3 ['cg24665113', 'cg16078210', 'cg16175703']
# │   ├── ('Superfamily_code', 'EMBRY')               : type: list, len: 3 ['cg14710529', 'cg16410524', 'cg03909863']
# │   ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: list, len: 3 ['cg09884146', 'cg07060794', 'cg03350900']
# │   ├── ('Superfamily_code', 'HEMA')                : type: list, len: 3 ['cg02081701', 'cg10124651', 'cg04737131']
# │   ├── ('Superfamily_code', 'MELANO')              : type: list, len: 3 ['cg03110368', 'cg02675308', 'cg25506747']
# │   ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: list, len: 3 ['cg17645677', 'cg01207684', 'cg13628022']
# │   ├── ('Superfamily_code', 'PIN_RET')             : type: list, len: 3 ['cg15188398', 'cg21185289', 'cg15157241']
# │   ├── ('Superfamily_code', 'SELLAR')              : type: list, len: 3 ['cg06132069', 'cg24862202', 'cg15337521']
# │   ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: list, len: 3 ['cg17090968', 'cg11235391', 'cg04209913']
# │   ├── ('Family_code', 'CNTL_BRAIN')               : type: list, len: 3 ['cg05876564', 'cg22630748', 'cg12819548']
# │   ├── ('Family_code', 'CRANIO')                   : type: list, len: 3 ['cg24164564', 'cg16759416', 'cg13754720']
# │   ├── ('Family_code', 'CTRL_TME')                 : type: list, len: 3 ['cg04209913', 'cg14365143', 'cg10193711']
# │   ├── ('Family_code', 'EPENDYM')                  : type: list, len: 3 ['cg02928365', 'cg09056876', 'cg12284769']
# │   ├── ('Family_code', 'ESTHESIO')                 : type: list, len: 3 ['cg07307388', 'cg25957967', 'cg07586489']
# │   ├── ('Family_code', 'GLIONEUR_NEUR')            : type: list, len: 3 ['cg14064526', 'cg09056876', 'cg27508055']
# │   ├── ('Family_code', 'HGG')                      : type: list, len: 3 ['cg20302533', 'cg14279121', 'cg06480736']
# │   ├── ('Family_code', 'MB')                       : type: list, len: 3 ['cg04209913', 'cg15837233', 'cg25479916']
# │   ├── ('Family_code', 'OTHER_EMBRY')              : type: list, len: 3 ['cg11242791', 'cg17904575', 'cg00699569']
# │   ├── ('Family_code', 'PAP_PINEAL')               : type: list, len: 3 ['cg21376454', 'cg16406892', 'cg16449012']
# │   ├── ('Family_code', 'PINEOBLAST')               : type: list, len: 3 ['cg25778892', 'cg18947175', 'cg12173150']
# │   ├── ('Family_code', 'PIT_AD')                   : type: list, len: 3 ['cg03625415', 'cg26380106', 'cg11412046']
# │   ├── ('Family_code', 'PLEXUS')                   : type: list, len: 3 ['cg11095319', 'cg25093234', 'cg10623600']
# │   ├── ('Family_code', 'SFT')                      : type: list, len: 3 ['cg08684879', 'cg24106661', 'cg03669394']
# │   └── ('Family_code', 'UNCERT_DIFF')              : type: list, len: 3 ['cg11165254', 'cg09814029', 'cg03094555']
# ├── optuna                         : type: dict, len: 26 {'Full_model': {'KNN': {'study': <optuna.study.study.Study object at 0x2b35c8200>, 'best_params': {'...
# │   ├── Full_model                                  : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b35c8200>, 'best_params': {'n_neighbors': 2...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b35c8200>, 'best_params': {'n_neighbors': 22, 'weig...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b35c8200>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 22, 'weights': 'uniform', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 22
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 0.8542788926843987
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A False
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x147a04200>, 'best_params': {'n_estimators': 850, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x147a04200>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}
# │   │       │   ├── n_estimators     : type: int, len: N/A 850
# │   │       │   ├── max_depth        : type: int, len: N/A 4
# │   │       │   └── min_samples_split: type: int, len: N/A 4
# │   │       ├── best_value   : type: float, len: N/A 0.8796031427326194
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A True
# │   ├── ('Superfamily_code', 'CNTRL')               : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b1ec7020>, 'best_params': {'n_neighbors': 2...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b1ec7020>, 'best_params': {'n_neighbors': 2, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b1ec7020>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'distance', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 2
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 2
# │   │   │   ├── best_value   : type: float, len: N/A 1.0
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b353e6c0>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b353e6c0>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 1.0
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Superfamily_code', 'CRAN_PARASPIN')       : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b359e510>, 'best_params': {'n_neighbors': 3...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b359e510>, 'best_params': {'n_neighbors': 3, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b359e510>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 3, 'weights': 'uniform', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 3
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# │   │   │   │   └── p          : type: int, len: N/A 2
# │   │   │   ├── best_value   : type: float, len: N/A 1.0
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b1f37470>, 'best_params': {'n_estimators': 563, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b1f37470>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}
# │   │       │   ├── n_estimators     : type: int, len: N/A 563
# │   │       │   ├── max_depth        : type: int, len: N/A 21
# │   │       │   └── min_samples_split: type: int, len: N/A 2
# │   │       ├── best_value   : type: float, len: N/A 1.0
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Superfamily_code', 'EMBRY')               : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b35697c0>, 'best_params': {'n_neighbors': 6...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b35697c0>, 'best_params': {'n_neighbors': 6, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b35697c0>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 6, 'weights': 'distance', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 6
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 0.9888888888888889
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b1ec5430>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b1ec5430>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 0.9888888888888889
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Superfamily_code', 'GLIOMA_GLIONEUR_NEUR'): type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b1fc1ca0>, 'best_params': {'n_neighbors': 1...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b1fc1ca0>, 'best_params': {'n_neighbors': 11, 'weig...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b1fc1ca0>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 11, 'weights': 'distance', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 11
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 0.8482340813720124
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A False
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b359e810>, 'best_params': {'n_estimators': 437, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b359e810>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 437, 'max_depth': 103, 'min_samples_split': 10}
# │   │       │   ├── n_estimators     : type: int, len: N/A 437
# │   │       │   ├── max_depth        : type: int, len: N/A 103
# │   │       │   └── min_samples_split: type: int, len: N/A 10
# │   │       ├── best_value   : type: float, len: N/A 0.8547162926473272
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A True
# │   ├── ('Superfamily_code', 'HEMA')                : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b353c890>, 'best_params': {'n_neighbors': 2...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b353c890>, 'best_params': {'n_neighbors': 2, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b353c890>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 2
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# │   │   │   │   └── p          : type: int, len: N/A 2
# │   │   │   ├── best_value   : type: float, len: N/A 1.0
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b364f830>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b364f830>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 1.0
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Superfamily_code', 'MELANO')              : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b359ee40>, 'best_params': {'n_neighbors': 3...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b359ee40>, 'best_params': {'n_neighbors': 3, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b359ee40>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 3, 'weights': 'distance', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 3
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 1.0
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b359edb0>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b359edb0>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 1.0
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Superfamily_code', 'MESEN_NONMENING')     : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b3569580>, 'best_params': {'n_neighbors': 5...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3569580>, 'best_params': {'n_neighbors': 5, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3569580>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 5
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# │   │   │   │   └── p          : type: int, len: N/A 2
# │   │   │   ├── best_value   : type: float, len: N/A 0.9398148148148149
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b353e210>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b353e210>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 0.9166666666666666
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Superfamily_code', 'PIN_RET')             : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b365adb0>, 'best_params': {'n_neighbors': 4...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b365adb0>, 'best_params': {'n_neighbors': 4, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b365adb0>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 4, 'weights': 'distance', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 4
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 0.9458333333333333
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b1fc3260>, 'best_params': {'n_estimators': 563, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b1fc3260>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}
# │   │       │   ├── n_estimators     : type: int, len: N/A 563
# │   │       │   ├── max_depth        : type: int, len: N/A 21
# │   │       │   └── min_samples_split: type: int, len: N/A 2
# │   │       ├── best_value   : type: float, len: N/A 0.9458333333333333
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Superfamily_code', 'SELLAR')              : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b1f25fd0>, 'best_params': {'n_neighbors': 5...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b1f25fd0>, 'best_params': {'n_neighbors': 5, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b1f25fd0>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 5, 'weights': 'uniform', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 5
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# │   │   │   │   └── p          : type: int, len: N/A 2
# │   │   │   ├── best_value   : type: float, len: N/A 0.9517746913580248
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A False
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3659fd0>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3659fd0>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 0.98070987654321
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A True
# │   ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b3682ba0>, 'best_params': {'n_neighbors': 6...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3682ba0>, 'best_params': {'n_neighbors': 6, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3682ba0>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 6, 'weights': 'distance', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 6
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 0.9196428571428572
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3680e60>, 'best_params': {'n_estimators': 850, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3680e60>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 850, 'max_depth': 4, 'min_samples_split': 4}
# │   │       │   ├── n_estimators     : type: int, len: N/A 850
# │   │       │   ├── max_depth        : type: int, len: N/A 4
# │   │       │   └── min_samples_split: type: int, len: N/A 4
# │   │       ├── best_value   : type: float, len: N/A 0.9166666666666666
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Family_code', 'CNTL_BRAIN')               : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b36595e0>, 'best_params': {'n_neighbors': 5...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b36595e0>, 'best_params': {'n_neighbors': 5, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b36595e0>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 5, 'weights': 'distance', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 5
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 1.0
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b36806b0>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b36806b0>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 0.9833333333333334
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Family_code', 'CRANIO')                   : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b3697290>, 'best_params': {'n_neighbors': 2...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3697290>, 'best_params': {'n_neighbors': 2, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3697290>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 2
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# │   │   │   │   └── p          : type: int, len: N/A 2
# │   │   │   ├── best_value   : type: float, len: N/A 1.0
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b0a488c0>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b0a488c0>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 1.0
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Family_code', 'CTRL_TME')                 : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b3666f00>, 'best_params': {'n_neighbors': 2...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3666f00>, 'best_params': {'n_neighbors': 2, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3666f00>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 2
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# │   │   │   │   └── p          : type: int, len: N/A 2
# │   │   │   ├── best_value   : type: float, len: N/A 1.0
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3680470>, 'best_params': {'n_estimators': 639, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3680470>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
# │   │       │   ├── n_estimators     : type: int, len: N/A 639
# │   │       │   ├── max_depth        : type: int, len: N/A 3
# │   │       │   └── min_samples_split: type: int, len: N/A 3
# │   │       ├── best_value   : type: float, len: N/A 1.0
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Family_code', 'EPENDYM')                  : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b361f8f0>, 'best_params': {'n_neighbors': 6...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b361f8f0>, 'best_params': {'n_neighbors': 6, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b361f8f0>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 6, 'weights': 'distance', 'p': 1}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 6
# │   │   │   │   ├── weights    : type: str, len: N/A distance
# │   │   │   │   └── p          : type: int, len: N/A 1
# │   │   │   ├── best_value   : type: float, len: N/A 0.9814814814814815
# │   │   │   └── IS_BEST_MODEL: type: bool, len: N/A True
# │   │   └── RF : type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b3682870>, 'best_params': {'n_estimators': 563, 'ma...
# │   │       ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b3682870>
# │   │       ├── best_params  : type: dict, len: 3 {'n_estimators': 563, 'max_depth': 21, 'min_samples_split': 2}
# │   │       │   ├── n_estimators     : type: int, len: N/A 563
# │   │       │   ├── max_depth        : type: int, len: N/A 21
# │   │       │   └── min_samples_split: type: int, len: N/A 2
# │   │       ├── best_value   : type: float, len: N/A 0.9814814814814815
# │   │       └── IS_BEST_MODEL: type: bool, len: N/A False
# │   ├── ('Family_code', 'ESTHESIO')                 : type: dict, len: 2 {'KNN': {'study': <optuna.study.study.Study object at 0x2b361c620>, 'best_params': {'n_neighbors': 2...
# │   │   ├── KNN: type: dict, len: 4 {'study': <optuna.study.study.Study object at 0x2b361c620>, 'best_params': {'n_neighbors': 2, 'weigh...
# │   │   │   ├── study        : type: Study, len: N/A <optuna.study.study.Study object at 0x2b361c620>
# │   │   │   ├── best_params  : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
# │   │   │   │   ├── n_neighbors: type: int, len: N/A 2
# │   │   │   │   ├── weights    : type: str, len: N/A uniform
# ...
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Superfamily_code', 'PIN_RET')             : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 4, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 4, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 4
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 0.9458333333333333
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Superfamily_code', 'SELLAR')              : type: dict, len: 8 {'model_key': 'RF', 'params': {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}, 'metric...
#     │   ├── model_key            : type: str, len: N/A RF
#     │   ├── params               : type: dict, len: 3 {'n_estimators': 639, 'max_depth': 3, 'min_samples_split': 3}
#     │   │   ├── n_estimators     : type: int, len: N/A 639
#     │   │   ├── max_depth        : type: int, len: N/A 3
#     │   │   └── min_samples_split: type: int, len: N/A 3
#     │   ├── metric_performance   : type: float, len: N/A 0.98070987654321
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'CIRC_ASTR_GLIO')           : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 6, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 6, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 6
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 0.9196428571428572
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'CNTL_BRAIN')               : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 5, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 5, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 5
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'CRANIO')                   : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
#     │   │   ├── n_neighbors: type: int, len: N/A 2
#     │   │   ├── weights    : type: str, len: N/A uniform
#     │   │   └── p          : type: int, len: N/A 2
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A False
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'CTRL_TME')                 : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
#     │   │   ├── n_neighbors: type: int, len: N/A 2
#     │   │   ├── weights    : type: str, len: N/A uniform
#     │   │   └── p          : type: int, len: N/A 2
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A False
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'EPENDYM')                  : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 6, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 6, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 6
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 0.9814814814814815
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'ESTHESIO')                 : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
#     │   │   ├── n_neighbors: type: int, len: N/A 2
#     │   │   ├── weights    : type: str, len: N/A uniform
#     │   │   └── p          : type: int, len: N/A 2
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A False
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'GLIONEUR_NEUR')            : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 5, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 5, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 5
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 0.9841269841269842
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'HGG')                      : type: dict, len: 8 {'model_key': 'RF', 'params': {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}, 'metric...
#     │   ├── model_key            : type: str, len: N/A RF
#     │   ├── params               : type: dict, len: 3 {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 6}
#     │   │   ├── n_estimators     : type: int, len: N/A 225
#     │   │   ├── max_depth        : type: int, len: N/A 6
#     │   │   └── min_samples_split: type: int, len: N/A 6
#     │   ├── metric_performance   : type: float, len: N/A 0.8737373737373737
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'MB')                       : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 3, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 3, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 3
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'OTHER_EMBRY')              : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 5, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 5, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 5
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 0.9888888888888889
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'PAP_PINEAL')               : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
#     │   │   ├── n_neighbors: type: int, len: N/A 2
#     │   │   ├── weights    : type: str, len: N/A uniform
#     │   │   └── p          : type: int, len: N/A 2
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A False
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'PINEOBLAST')               : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
#     │   │   ├── n_neighbors: type: int, len: N/A 2
#     │   │   ├── weights    : type: str, len: N/A uniform
#     │   │   └── p          : type: int, len: N/A 2
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A False
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'PIT_AD')                   : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 4, 'weights': 'uniform', 'p': 2}
#     │   │   ├── n_neighbors: type: int, len: N/A 4
#     │   │   ├── weights    : type: str, len: N/A uniform
#     │   │   └── p          : type: int, len: N/A 2
#     │   ├── metric_performance   : type: float, len: N/A 0.9365079365079367
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'PLEXUS')                   : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 3, 'weights': 'distance', 'p': 1}, 'metric_performanc...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 3, 'weights': 'distance', 'p': 1}
#     │   │   ├── n_neighbors: type: int, len: N/A 3
#     │   │   ├── weights    : type: str, len: N/A distance
#     │   │   └── p          : type: int, len: N/A 1
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A True
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc_ovr
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     ├── ('Family_code', 'SFT')                      : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#     │   ├── model_key            : type: str, len: N/A KNN
#     │   ├── params               : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
#     │   │   ├── n_neighbors: type: int, len: N/A 2
#     │   │   ├── weights    : type: str, len: N/A uniform
#     │   │   └── p          : type: int, len: N/A 2
#     │   ├── metric_performance   : type: float, len: N/A 1.0
#     │   ├── is_multi_class       : type: bool, len: N/A False
#     │   ├── n_trials             : type: int, len: N/A 10
#     │   ├── cv_folds             : type: int, len: N/A 3
#     │   ├── metric_to_optimize   : type: str, len: N/A roc_auc
#     │   └── direction_to_optimize: type: str, len: N/A maximize
#     └── ('Family_code', 'UNCERT_DIFF')              : type: dict, len: 8 {'model_key': 'KNN', 'params': {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}, 'metric_performance...
#         ├── model_key            : type: str, len: N/A KNN
#         ├── params               : type: dict, len: 3 {'n_neighbors': 2, 'weights': 'uniform', 'p': 2}
#         │   ├── n_neighbors: type: int, len: N/A 2
#         │   ├── weights    : type: str, len: N/A uniform
#         │   └── p          : type: int, len: N/A 2
#         ├── metric_performance   : type: float, len: N/A 1.0
#         ├── is_multi_class       : type: bool, len: N/A False
#         ├── n_trials             : type: int, len: N/A 10
#         ├── cv_folds             : type: int, len: N/A 3
#         ├── metric_to_optimize   : type: str, len: N/A roc_auc
#         └── direction_to_optimize: type: str, len: N/A maximize

# %% [markdown]
# # ,.-,.-,.-,.-,.-,.-,.-,.-,.-,.-,.-,.-,.-,.-,.-,.-

# %%
global_key = ('Superfamily_code', 'CNTRL')

# %%
# get the DF ready to train 
sample_row_idx = mega_dict['sample_dict'][global_key]
target_key = mega_dict['target_key_dict'][global_key]
feature_col_idx = mega_dict['RF_selected_feature_dict'][global_key]

combined_columns = target_key + feature_col_idx
selected_df = df.loc[sample_row_idx, combined_columns]
selected_df
# Out:
#      Family_code  cg03683087  cg10623600  cg05876564
# 65      CTRL_TME    0.401081    0.091869    0.407584
# 71    CNTL_BRAIN    0.944885    0.282652    0.956408
# 72    CNTL_BRAIN    0.923624    0.473825    0.977495
# 74    CNTL_BRAIN    0.872861    0.063055    0.943896
# 76      CTRL_TME    0.394462    0.101425    0.673135
# 86      CTRL_TME    0.376026    0.152454    0.587162
# 112   CNTL_BRAIN    0.808169    0.321156    0.480948
# 113   CNTL_BRAIN    0.748624    0.206338    0.553117
# 114   CNTL_BRAIN    0.795445    0.306409    0.425611
# 148   INFLAM_ENV    0.078742    0.088563    0.209184
# 160  NORM_PINEAL    0.218834    0.427485    0.914738
# 164  NORM_PINEAL    0.313250    0.641794    0.915262
# 195  NORM_PINEAL    0.337423    0.705960    0.912421
# 224   CNTL_BRAIN    0.818416    0.549696    0.895185
# 225   CNTL_BRAIN    0.809767    0.712272    0.938802
# 226   CNTL_BRAIN    0.886296    0.650387    0.936453
# 239     CTRL_TME    0.918133    0.826820    0.337340
# 240     CTRL_TME    0.941796    0.899756    0.473455
# 241     CTRL_TME    0.864920    0.711852    0.456901
# 250   INFLAM_ENV    0.044271    0.040045    0.395780
# 251   INFLAM_ENV    0.043396    0.046385    0.105706
# 263   CNTL_BRAIN    0.868658    0.549377    0.650838
# 264   CNTL_BRAIN    0.894368    0.453762    0.658763
# 265   CNTL_BRAIN    0.719916    0.547048    0.726726
# 267   CNTL_BRAIN    0.890432    0.234138    0.435518
# 268   CNTL_BRAIN    0.645772    0.184995    0.515666
# 269   CNTL_BRAIN    0.669006    0.223783    0.555499

# %%
# load preset model typ enad model params 


mega_dict['best_optuna_model_info'][global_key]
"""
here is where having a standard name for each model type would be super helpful and why it is workth your time to do this 




"""
# Out:
# {'model_key': 'KNN',
#  'params': {'n_neighbors': 2, 'weights': 'distance', 'p': 2},
#  'metric_performance': 1.0,
#  'is_multi_class': True,
#  'n_trials': 10,
#  'cv_folds': 3,
#  'metric_to_optimize': 'roc_auc_ovr',
#  'direction_to_optimize': 'maximize'}
